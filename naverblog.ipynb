# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas  as pd 
import psycopg2
from datetime import date, timedelta

# %% [markdown]
# 뷔스티에 원피스, 롱패딩, 숏패딩, 롱코트, 숏코트, 잠옷, 홈웨어, 트위드자켓

# %%
driver = webdriver.Chrome('C:\chromedriver.exe')

#크롬드라이버 실행
driver.get('http://www.naver.com')
time.sleep(2)

#키워드를 검색한 네이버창 접속
query_txt = '트위드자켓'
element = driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

# 뷰 클릭
driver.find_element_by_link_text("VIEW").click()
time.sleep(2)

#필터 클릭
driver.find_element_by_xpath('//*[@id="snb"]/div[1]/div/div[3]/a').click()
time.sleep(2)

#기간 1년 설정
driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[3]/div/div[1]/a[8]').click()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8060/2934624994.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\chromedriver.exe')
# C:\Users\User\AppData\Local\Temp/ipykernel_8060/2934624994.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id("query")
# C:\Users\User\AppData\Local\Temp/ipykernel_8060/2934624994.py:14: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   driver.find_element_by_link_text("VIEW").click()
# C:\Users\User\AppData\Local\Temp/ipykernel_8060/2934624994.py:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="snb"]/div[1]/div/div[3]/a').click()
# C:\Users\User\AppData\Local\Temp/ipykernel_8060/2934624994.py:22: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[3]/div/div[1]/a[8]').click()

# %%
no2 = [ ]           # 게시글 번호 컬럼
title2 = [ ]        # 게시물 제목 컬럼
bdate2 = [ ]        # 작성 일자 컬럼
url2 = [ ]          # 블로그 url 주소

# %%
no = 1

# 자동 스크롤다운 함수
def scroll_down(driver):
  driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
  time.sleep(5)


#더이상 스크롤이 안되면 종료
i = 1
time.sleep(1)

#현재 스크롤 위치를 last_height로 받아옴
last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    #스크롤 한 번 실행 후 스크롤 위치를 new_height로 받아옴
    scroll_down(driver)
    new_height = driver.execute_script("return document.documentElement.scrollHeight")

    #더이상 스크롤이 안되면 종료
    if new_height == last_height:
        break

    last_height = new_height
    i += 1


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

view_list = soup.find('ul','lst_total').find_all('li')
print('포스트 개수 :', len(view_list))

for i in view_list :
    
    no2.append(no)                            # 게시물 번호 리스트에 추가
    print('진행 중:',no)

    all_title = i.find_all('a')
    title = all_title[5].get_text( )          # 게시물 제목
    title2.append(title)                      # 게시물 제목 리스트에 추가

    time.sleep(2)

    bdate = i.find('span','sub_time sub_txt').get_text( )  # 작성일자
    bdate.replace('.', '-')
    bdate2.append(bdate)                     # 작성일자 리스트에 추가

    time.sleep(2)

    url = str(all_title[0])
    url = url.split('"')[5]                 # 게시물 url
    url2.append(url)                        # url 리스트에 추가

    time.sleep(2)

    if no == 200 : #한번에 200개 까지만 크롤링 가능
        break
        
    no += 1

print('끝')
# Out:
# 포스트 개수 : 79
# 진행 중: 1
# 진행 중: 2
# 진행 중: 3
# 진행 중: 4
# 진행 중: 5
# 진행 중: 6
# 진행 중: 7
# 진행 중: 8
# 진행 중: 9
# 진행 중: 10
# 진행 중: 11
# 진행 중: 12
# 진행 중: 13
# 진행 중: 14
# 진행 중: 15
# 진행 중: 16
# 진행 중: 17
# 진행 중: 18
# 진행 중: 19
# 진행 중: 20
# 진행 중: 21
# 진행 중: 22
# 진행 중: 23
# 진행 중: 24
# 진행 중: 25
# 진행 중: 26
# 진행 중: 27
# 진행 중: 28
# 진행 중: 29
# 진행 중: 30
# 진행 중: 31
# 진행 중: 32
# 진행 중: 33
# 진행 중: 34
# 진행 중: 35
# 진행 중: 36
# 진행 중: 37
# 진행 중: 38
# 진행 중: 39
# 진행 중: 40
# 진행 중: 41
# 진행 중: 42
# 진행 중: 43
# 진행 중: 44
# 진행 중: 45
# 진행 중: 46
# 진행 중: 47
# 진행 중: 48
# 진행 중: 49
# 진행 중: 50
# 진행 중: 51
# 진행 중: 52
# 진행 중: 53
# 진행 중: 54
# 진행 중: 55
# 진행 중: 56
# 진행 중: 57
# 진행 중: 58
# 진행 중: 59
# 진행 중: 60
# 진행 중: 61
# 진행 중: 62
# 진행 중: 63
# 진행 중: 64
# 진행 중: 65
# 진행 중: 66
# 진행 중: 67
# 진행 중: 68
# 진행 중: 69
# 진행 중: 70
# 진행 중: 71
# 진행 중: 72
# 진행 중: 73
# 진행 중: 74
# 진행 중: 75
# 진행 중: 76
# 진행 중: 77
# 진행 중: 78
# 진행 중: 79
# 끝

# %%
bdate3 = [] #전처리 후 작성일자

# 작성일자를 날짜형식으로 통일화
for day in bdate2 :

    if '시간 전' in day :       # n시간 전 업로드 글
        day = date.today()
    elif '분 전' in day :       # n분 전 업로드 글
        day = date.today()
    elif '일 전' in day :       # n일 전 업로드 글 
        day = date.today() - timedelta(int(day[0])) #8일전 글 부터는 날짜로 반환
    elif day == '어제' :        # 어제 업로드 글
        day = date.today() - timedelta(1)
    else :
        day = day.rstrip('.')
        day = day.replace('.', '-')
    
    bdate3.append(day)

# df화
naver_blog = pd.DataFrame()
naver_blog['제목'] = title2
naver_blog['작성일자'] = bdate3
naver_blog['주소'] = url2

#date-time 타입으로 변환
naver_blog['작성일자'] = pd.to_datetime(naver_blog['작성일자'])

naver_blog.head()
# Out:
#                                               제목       작성일자  \
# 0                        온앤온 트위드 자켓 결혼식 하객룩으로 좋아 2022-02-08
# 1                          여성트위드자켓 핑크 셔츠카라로 시크하게 2022-05-22
# 2              여자 봄패션 블라우스 코디 트위드자켓 내돈내산후 해본 후기! 2022-03-31
# 3                 어김없이 트위드의 계절이돌아왔다! (feat. 하객룩) 2022-03-24
# 4  moodndress 린넨반팔트위드자켓 여름자켓 반팔자켓 골드버튼자켓 여름코디 마켓 2022-05-25
#
#                                                   주소
# 0         https://blog.naver.com/ssdria/222642107472
# 1          https://blog.naver.com/xixhk/222740770238
# 2    https://blog.naver.com/bushcherry1/222687734857
# 3  https://post.naver.com/viewer/postView.naver?v...
# 4     https://blog.naver.com/moodndress/222745763570

# %%
#select문 만들기
def select_command(table) :
    command = 'select * from ' + table
    return command

#insert문 만들기
def insert_command(table) :
    command = 'insert into ' + table + ' (title, date, url) values (%s, %s, %s);'
    return command

# %%
#postgresql 접속
conn_string = "host='localhost' dbname='postgres' user='postgres' password='admin'"
conn = psycopg2.connect(conn_string)
cur = conn.cursor()

table = input('테이블명 입력 :')

#table에 데이터 넣기
for i in range(len(naver_blog)) :
    cur.execute(insert_command(table), (naver_blog.iloc[i][0], naver_blog.iloc[i][1], naver_blog.iloc[i][2]))
    conn.commit()

# %%
#table 확인하기
cur.execute(select_command(table))
conn.commit()
cur.fetchall()
# Out:
# [(1,
#   '뷔스티에 원피스 코디. BYC 롱원피스 편안해',
#   datetime.date(2022, 4, 26),
#   'https://blog.naver.com/sunkjydbgn/222711874385'),
#  (2,
#   'BYC 원피스 린넨 뷔스티에원피스로 여름준비 완료',
#   datetime.date(2022, 4, 26),
#   'https://blog.naver.com/hellobear28/222711338374'),
#  (3,
#   '아벨라제이 뷔스티에원피스 여성스러워요',
#   datetime.date(2022, 2, 20),
#   'https://blog.naver.com/ssong920/222653008098'),
#  (4,
#   '오마이걸 아린 뷔스티에 롱 원피스 후기 : 여름코디 추천해요 @BYC',
#   datetime.date(2022, 4, 26),
#   'https://blog.naver.com/lsosvbe7/222712051667'),
#  (5,
#   '뷔스티에 원피스 편안하고 시원해 여름에 딱! BYC',
#   datetime.date(2022, 4, 22),
#   'https://blog.naver.com/loveholic_/222707879541'),
#  (6,
#   '워너비워너미 4월 추천코디(플라워원피스, 반팔블라우스, 와이드슬랙스, 트임셔츠)',
#   datetime.date(2022, 4, 5),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=33574349&amp;memberNo=1901247&amp;vType=VERTICAL'),
#  (7,
#   '여성 도트 원피스 코디 - 봄, 여름까지 가능한 땡땡이 롱원피스 추천│#쉬폰 #뷔스티에',
#   datetime.date(2022, 3, 21),
#   'https://blog.naver.com/syous0/222678338315'),
#  (8,
#   '21FW 콜라보토리 롱원피스 & 뷔스티에 탑 리뷰',
#   datetime.date(2021, 11, 12),
#   'https://blog.naver.com/jayuyu/222566227229'),
#  (9,
#   'BYC 뷔스티에 원피스 시원하고 편안해',
#   datetime.date(2022, 4, 26),
#   'https://blog.naver.com/cherry_202/222711830394'),
#  (10,
#   '린넨소재의 뷔스티에 원피스 쾌적한 BYC 롱 여름 원피스',
#   datetime.date(2022, 4, 25),
#   'https://blog.naver.com/arafatare/222710547618'),
#  (11,
#   '썸머 텐션세트 뷔스티에원피스 올해도 진행 인기 탑인 상품이에요',
#   datetime.date(2022, 4, 21),
#   'https://cafe.naver.com/hotdealcommunity/1897610'),
#  (12,
#   '이중거즈 꽃무늬원단으로 여아 뷔스티에 원피스 함께 입을 반팔도 만들기',
#   datetime.date(2022, 4, 29),
#   'https://blog.naver.com/ghdudqlcskfr/222715848156'),
#  (13,
#   '여름원피스로 BYC 뷔스티에 원피스 장만했어요!',
#   datetime.date(2022, 4, 25),
#   'https://blog.naver.com/rhdmswls14/222710775471'),
#  (14,
#   '돈포겟미 볼캡 코디 - 육육걸즈 카라 니트랑 커먼유니크 뷔스티에 원피스 데일리룩 코디',
#   datetime.date(2022, 5, 16),
#   'https://blog.naver.com/itsmese_e/222733152571'),
#  (15,
#   'H&M X 브록 컬렉션 콜라보 여름 민소매 뷔스티에 원피스 플라워 추천',
#   datetime.date(2021, 6, 1),
#   'https://blog.naver.com/ssdria/222378947195'),
#  (16,
#   '유니크 레이어드 체크 뷔스티에 끈나시원피스',
#   datetime.date(2021, 7, 14),
#   'https://blog.naver.com/3040814/222431871442'),
#  (17,
#   '[비밀클로젯] 베니스 셔링원피스 2colors / 아모르 뷔스티에원피스 / 버블 블라우스5 colors _ 16일...',
#   datetime.date(2022, 5, 11),
#   'https://blog.naver.com/secret_jangsingu/222728977363'),
#  (18,
#   '[20 30대 여성의류쇼핑몰 때깔닷컴] 뷔스티에 캉캉 벨벳 원피스',
#   datetime.date(2021, 12, 15),
#   'https://blog.naver.com/bijourjf/222596396269'),
#  (19,
#   '남자들 여자 뷔스티에 원피스 입는 거 싫어한다고 하잖아여',
#   datetime.date(2022, 5, 6),
#   'https://cafe.naver.com/dieselmania/38100083'),
#  (20,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/cjcjmom/3029012'),
#  (21,
#   '[컬리수] 키즈 뷔스티에 원피스 코디 추천!',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/curlysuemom/222743242851'),
#  (22,
#   '5월 기온별옷차림 :: 아뜨랑스 셔츠와 뷔스티에 원피스(13도, 28도 옷차림)',
#   datetime.date(2022, 5, 23),
#   'https://blog.naver.com/dkksii/222742191455'),
#  (23,
#   '식스센스2 전소민 듀엘 뷔스티에 원피스 이쁘다!',
#   datetime.date(2021, 7, 5),
#   'https://blog.naver.com/ppeunimama/222420965732'),
#  (24,
#   '[ RIzcloset ] 프릴 블라우스와 뷔스티에 플레어 롱 원피스 Update',
#   datetime.date(2021, 12, 7),
#   'https://blog.naver.com/k_riz529/222589403616'),
#  (25,
#   '우리들의 블루스 한지민 원피스, 한지민뷔스티에 원피스 정보',
#   datetime.date(2022, 5, 9),
#   'https://blog.naver.com/amdacc/222726271700'),
#  (26,
#   '쿨 나시 레이어드 뷔스티에 롱 원피스',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/tjswn744/222727075424'),
#  (27,
#   '아이싱 뷔스티에원피스 쿨링감소재 완죤 시원시원~♡',
#   datetime.date(2022, 5, 19),
#   'https://cafe.naver.com/hotdealcommunity/1938851'),
#  (28,
#   '프롬 뷔스티에 스퀘어넥 롱원피스 구매 후기 (아뜨랑스)',
#   datetime.date(2021, 6, 16),
#   'https://blog.naver.com/gtedhsdo/222400457715'),
#  (29,
#   '트위드 겨울 뷔스티에 롱원피스',
#   datetime.date(2021, 11, 17),
#   'https://blog.naver.com/kal1728/222571039621'),
#  (30,
#   '리리앤코 배송 후기 더펜든 블라우스 핀턱 뷔스티에 롱 원피스 세트',
#   datetime.date(2021, 9, 12),
#   'https://blog.naver.com/baemju/222503021350'),
#  (31,
#   '린넨 뷔스티에 끈나시 롱 원피스 3color',
#   datetime.date(2022, 5, 18),
#   'https://blog.naver.com/qsxc1995/222737437044'),
#  (32,
#   '이번주 다음주 MY 봄패션 코디, 더 더워지기 전에 뷔스티에 롱 원피스 자주 입을 거야!',
#   datetime.date(2022, 5, 1),
#   'https://blog.naver.com/elleest486/222717299308'),
#  (33,
#   '뷔스티에원피스 메리옵스 도트 리본 뒷밴딩 뷔스티에 롱 원피스!',
#   datetime.date(2021, 8, 29),
#   'https://blog.naver.com/ww4953/222487853067'),
#  (34,
#   '바라던바다 3회 로제 뷔스티에 원피스 @케이트 KHAITE Robin dress',
#   datetime.date(2021, 7, 15),
#   'https://blog.naver.com/pinkleo035/222432357648'),
#  (35,
#   'A라인 보카시 브이넥 미니 겨울뷔스티에원피스',
#   datetime.date(2021, 11, 13),
#   'https://blog.naver.com/hi_rit/222566989144'),
#  (36,
#   '<세실리아반센> 헤더 포플린 뷔스티에 원피스',
#   datetime.date(2022, 2, 26),
#   'https://blog.naver.com/adorable_mh/222658005691'),
#  (37,
#   '리리앤코 배송 헤링본 랩 원피스 겨울 뷔스티에 좋아',
#   datetime.date(2022, 1, 8),
#   'https://blog.naver.com/tmdghk05/222616593759'),
#  (38,
#   '리리앤코 배송 총알 후기, 메리옵스 도트 리본 뒷밴딩 뷔스티에 롱 원피스',
#   datetime.date(2021, 8, 29),
#   'https://blog.naver.com/jihye7531/222479982115'),
#  (39,
#   '끈나시 롱원피스로 바캉스룩 해결 프롬데이원 나잇뷔스티에',
#   datetime.date(2021, 7, 17),
#   'https://blog.naver.com/1029-/222434548855'),
#  (40,
#   '활용도 좋은 절개 뷔스티에 롱 끈 원피스 코디하기',
#   datetime.date(2021, 10, 20),
#   'https://blog.naver.com/yahm1208/222542853068'),
#  (41,
#   '우리들의 블루스 9회 이영옥 한지민 옷 정보 에트몽 버블 뷔스티에 원피스',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/whit2sugar/222724291855'),
#  (42,
#   '홍윤화 원피스, 빅 사이즈 원피스 [ NAK 21 뷔스티에 원피스 ] 솔직 후기!',
#   datetime.date(2022, 5, 11),
#   'https://blog.naver.com/dlalsrud0614/222726329890'),
#  (43,
#   '패치 뷔스티에 원피스~',
#   datetime.date(2022, 3, 7),
#   'https://blog.naver.com/sachico33/222665786593'),
#  (44,
#   '30대미시쇼핑몰 - 플라워 레이스 뷔스티에 롱원피스~ 빅사이즈 원피스도 OK',
#   datetime.date(2021, 10, 22),
#   'https://blog.naver.com/pklaaa/222544694235'),
#  (45,
#   '여름원피스 활용도 만점 뷔스티에원피스 뽀데나',
#   datetime.date(2021, 7, 3),
#   'https://blog.naver.com/cool7927/222419214496'),
#  (46,
#   '김나영 인스타그램 패션 민트 셔츠, 뷔스티에 원피스 옷은 로우클래식',
#   datetime.date(2022, 4, 21),
#   'https://blog.naver.com/211115s/222707263147'),
#  (47,
#   '프라다 뷔스티에 원피스 . 스트링셔츠자켓 . 서커스 롤링티',
#   datetime.date(2021, 5, 30),
#   'https://blog.naver.com/mani0005/222375432317'),
#  (48,
#   '플라워 꽃패턴 뷔스티에 끈 원피스 레이어드룩 연출하기',
#   datetime.date(2021, 6, 3),
#   'https://blog.naver.com/mintchoco007/222382891333'),
#  (202,
#   '몽클레어 매장에 내일 가면 롱패딩 있을까요??',
#   datetime.date(2022, 5, 6),
#   'https://cafe.naver.com/parisienlook/3529741'),
#  (49,
#   '마켓[마이아르무아]나시 민소매 스퀘어넥 롱 원피스 플레어 에이라인 뷔스티에',
#   datetime.date(2022, 5, 4),
#   'https://blog.naver.com/kiki5942/222720804672'),
#  (50,
#   '[220307] 라젤 트위드 뷔스티에 원피스 베이지 & 라인케이 알파카 니트 데일리룩 및 일상',
#   datetime.date(2022, 3, 7),
#   'https://blog.naver.com/ilove_ji/222666392705'),
#  (51,
#   '5월 봄 직장인 데일리룩 / 뷔스티에 원피스 레이어드 코디, sjsj 아울렛 청바지, 스캘럽 가디건 추천!',
#   datetime.date(2022, 5, 20),
#   'https://blog.naver.com/z47444399/222739557430'),
#  (52,
#   'TNGTW 티엔지티 플라워 뷔스티에 원피스 바캉스룩 제격',
#   datetime.date(2022, 5, 19),
#   'https://blog.naver.com/5ehijo/222738816830'),
#  (53,
#   '린넨원피스코디, 30대워킹맘코디, 뷔스티에 원피스',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/minubaba84/222727459650'),
#  (54,
#   '여리 린넨 민소매 끈 원피스 (2colors) 롱 두줄 허리끈 스퀘어넥 뷔스티에 뷔스띠에 나시 심플',
#   datetime.date(2022, 5, 17),
#   'https://blog.naver.com/yhyhihi1/222735120264'),
#  (55,
#   '우리들의블루스 9회 한지민 원피스 옷 뷔스티에 에트몽 김우빈 머그컵 직진연하남',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/gkdud908/222724530975'),
#  (56,
#   '우리들의블루스 9회 한지민 옷 원피스 플라워 뷔스티에 에트몽 ETMON',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/kkomi8181/222724550239'),
#  (57,
#   '(가격공개) 레더숏자켓 / 뷔스티에원피스',
#   datetime.date(2022, 2, 24),
#   'https://blog.naver.com/jjjjiya1004/222657056102'),
#  (58,
#   '그린마더스클럽 3회 이은표 이요원 추자현 김규리 옷 원피스 뷔스티에 의상 패션',
#   datetime.date(2022, 4, 14),
#   'https://blog.naver.com/some1it_/222700165834'),
#  (59,
#   '우리들의블루스9화 한지민패션 뷔스티에원피스 어디꺼?',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/my_happiness_727/222724966933'),
#  (60,
#   '에바빈 랑데부 뷔스티에 캉캉 원피스 ( 메이윤 꺼 사려다 산 캉캉 스커트 )',
#   datetime.date(2022, 5, 19),
#   'https://blog.naver.com/032690h/222738691713'),
#  (61,
#   'REVIEW_ VICOLO 비콜로 : 새틴 드레스 (뷔스티에 원피스) #벚꽃룩 #베리페리',
#   datetime.date(2022, 4, 8),
#   'https://blog.naver.com/lhh7040/222694752577'),
#  (62,
#   '도트스커트/퍼프티/플라워뷔스티에원피스',
#   datetime.date(2022, 4, 18),
#   'https://blog.naver.com/oreo0725/222704125878'),
#  (63,
#   '로엠 뷔스티에 원피스 코디추천',
#   datetime.date(2022, 5, 4),
#   'https://blog.naver.com/wlswlsdk/222720560151'),
#  (64,
#   '코벳블랑 여름 뷔스티에 원피스 블라우스 S/S 화보',
#   datetime.date(2022, 5, 20),
#   'https://blog.naver.com/dbdudcksdl/222740237240'),
#  (65,
#   '우리들의 블루스 9회 한지민 옷 뷔스티에 원피스코디 러블리해',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/iamjina_26/222724275551'),
#  (66,
#   '빅사이즈 시스루 화이트가디건 플라워 뷔스티에원피스 투피스 세트',
#   datetime.date(2022, 5, 21),
#   'https://blog.naver.com/awesomegrow/222740516318'),
#  (67,
#   '20대여자데일리룩 뷔스티에 트위드원피스 모어슬리미',
#   datetime.date(2022, 5, 16),
#   'https://blog.naver.com/wldmsdl1113/222735022657'),
#  (68,
#   'OOTD 미샤 반팔자켓, 뷔스티에 롱원피스 코디,구찌 미니가방',
#   datetime.date(2022, 5, 21),
#   'https://blog.naver.com/martinal/222740846002'),
#  (69,
#   '행복여신상무배비비 플라워 브이 라인 뷔스티에 원피스 (15e03083-25f0)',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/zcjkxf3p/222744257571'),
#  (70,
#   '미쏘 플레어핏 뷔스티에 롱 원피스 (49c832aa-412a)',
#   datetime.date(2022, 5, 23),
#   'https://blog.naver.com/zzyf21k/222742577666'),
#  (71,
#   '썸머 텐션세트 뷔스티에원피스 올해도 진행 인기 탑인 상품이에요',
#   datetime.date(2022, 5, 18),
#   'https://cafe.naver.com/hotdealcommunity/1937848'),
#  (72,
#   '청치마 만들기.뷔스티에 원피스.브이넥 뷔스티에원피스.청 뷔스티에원피스만들기.',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/q07011/222725244258'),
#  (73,
#   '고급스런 울체크로 만들어본 겨울 뷔스티에 원피스,,',
#   datetime.date(2021, 12, 8),
#   'https://blog.naver.com/bosun1434/222590101903'),
#  (74,
#   '[ B.you :-) ] 뷔스티에 스토퍼끈 원피스',
#   datetime.date(2022, 5, 2),
#   'https://blog.naver.com/byoubu/222718074864'),
#  (75,
#   '페이퍼먼츠 드레쉬한 펄 뷔스티에 원피스 00361 (bdfbbff6-699b)',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/xdkv2447/222743790707'),
#  (76,
#   '자라 봄 신상 원피스 뷔스티에 원피스 & 플라워 패턴 노랑원피스',
#   datetime.date(2022, 2, 23),
#   'https://blog.naver.com/snowdrop0131/222655953651'),
#  (77,
#   '우리들의 블루스 9회 9화 한지민 원피스 뷔스티에 옷 신민아 가방 치마 스커트 패션',
#   datetime.date(2022, 5, 7),
#   'https://blog.naver.com/godko12/222724085673'),
#  (78,
#   '페이퍼먼츠 드레쉬한 펄 뷔스티에 원피스 00361 (3dbe303d-7189)',
#   datetime.date(2022, 5, 23),
#   'https://blog.naver.com/aas5dg0/222742958218'),
#  (79,
#   '행복여신상무배비비 플라워 브이 라인 뷔스티에 원피스 (622d36b8-ed31)',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/kouvpv/222743785532'),
#  (80,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/dodamdadam1004/2353070'),
#  (81,
#   '행복여신상무배비비 플라워 브이 라인 뷔스티에 원피스 (754f9866-3c6c)',
#   datetime.date(2022, 5, 18),
#   'https://blog.naver.com/cwra6rl1/222736680018'),
#  (82,
#   '쇼윈도 여왕의집 8회 전소민 레이스 코트 원피스 가방 옷 가디건 뷔스티에 패션 의상 정보 윤미라 8화 줄거리',
#   datetime.date(2021, 12, 23),
#   'https://blog.naver.com/hilung1234/222602436637'),
#  (83,
#   '재봉 : 뷔스티에 원피스',
#   datetime.date(2022, 5, 12),
#   'https://blog.naver.com/iammoone/222729677463'),
#  (84,
#   '우리들의 블루스 한지민 옷 롱원피스 뷔스티에 코디는 에트몽 ETMON',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/t22n82/222727533163'),
#  (85,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/dgmom365/5854405'),
#  (86,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/jinhaemam/1973123'),
#  (87,
#   '하늘색 가디건+레이스 뷔스티에 롱 원피스[찡어니look15]',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/yumiz_z/222743252082'),
#  (88,
#   '지금부터 쭈욱 입기좋은, 통기성이 뛰어나고 편안한 BYC 뷔스티에원피스',
#   datetime.date(2022, 4, 20),
#   'https://blog.naver.com/namse-zone/222705804860'),
#  (89,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/andongmom/603577'),
#  (90,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/baby8/2318809'),
#  (91,
#   '[핑퐁맘 여름신상 추천템]구찌 캉캉 뷔스티에 원피스',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/llso900/222727622337'),
#  (92,
#   '마쥬 여름 맥시 원피스 백오픈 뷔스티에 프린트 Maje outlet dress',
#   datetime.date(2022, 5, 17),
#   'https://blog.naver.com/shez44/222736052472'),
#  (93,
#   '트위드 원단으로 뷔스티에 원피스 만들기',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/vivifabric/222726575840'),
#  (94,
#   '뷔스티에원피스',
#   datetime.date(2022, 5, 17),
#   'https://blog.naver.com/hee-327/222736144251'),
#  (95,
#   '블랙 리본 뷔스티에 원피스',
#   datetime.date(2022, 5, 11),
#   'https://blog.naver.com/zzapagetee/222729059997'),
#  (96,
#   '♥빈티지_블랙 뷔스티에 원피스_하츠픽451',
#   datetime.date(2022, 5, 22),
#   'https://blog.naver.com/ha_tsu_v/222742220616'),
#  (203,
#   '롱패딩 세탁 ??',
#   datetime.date(2022, 3, 3),
#   'https://cafe.naver.com/masanmam/5929414'),
#  (97,
#   '비비에모 볼륨업 숄더 투라인 롱 뷔스티에 원피스 00184 (c9a0f3ba-d2d7)',
#   datetime.date(2022, 5, 23),
#   'https://blog.naver.com/mveqc5/222742374616'),
#  (98,
#   'Vintage blue wrap bl& lace navy dress /빈티지 랩 블라우스 & 네이비 레이스 뷔스티에 원피스',
#   datetime.date(2022, 5, 4),
#   'https://blog.naver.com/alwaysberomantic/222721096829'),
#  (99,
#   '이런 뷔스티에 원피스 사고싶은데 이런류를 뭐라구 할까여?',
#   datetime.date(2022, 4, 19),
#   'https://cafe.naver.com/cosmania/34503582'),
#  (100,
#   '[모데니롱 뷔스티에원피스] 레이어드로 넘좋아요! 보데니롱VT',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/ysbaby/234928'),
#  (101,
#   '코튼 면 스퀘어넥 a라인 민소매 어깨밴딩 나시 플레어 뷔스티에롱원피스 곱창밴딩어깨끈 밴딩주름어깨끈...',
#   datetime.date(2022, 5, 19),
#   'https://blog.naver.com/an1453ran/222739007906'),
#  (102,
#   '비비에모 볼륨업 숄더 투라인 롱 뷔스티에 원피스 00184 (735a6ff9-2d13)',
#   datetime.date(2022, 5, 18),
#   'https://blog.naver.com/purplegorilla103/222737331398'),
#  (103,
#   '썸머 텐션세트 블랑세트 뷔스티에원피스 올해도 진행 인기 탑인 상품이에요',
#   datetime.date(2022, 4, 29),
#   'https://cafe.naver.com/hotdealcommunity/1909409'),
#  (104,
#   '꽃 뷔스티에 원피스',
#   datetime.date(2022, 5, 17),
#   'https://cafe.naver.com/grayncgwx/72619'),
#  (105,
#   '하객룩 불호 뷔스티에원피스 룩',
#   datetime.date(2022, 5, 8),
#   'https://cafe.naver.com/dieselmania/38120606'),
#  (106,
#   '나인나인 민트 뷔스티에 원피스 Sd13사이즈로 구해요!!',
#   datetime.date(2022, 4, 22),
#   'https://cafe.naver.com/bjdfleamarket/136001'),
#  (107,
#   'a8315 뷔스티에 원피스',
#   datetime.date(2022, 5, 23),
#   'https://cafe.naver.com/9jedome/89335'),
#  (108,
#   '뷔스티에 원피스(핀턱 지옥)',
#   datetime.date(2022, 4, 15),
#   'https://cafe.naver.com/ggong2/982451'),
#  (109,
#   '체크모직 뷔스티에 원피스',
#   datetime.date(2022, 1, 11),
#   'https://cafe.naver.com/ggong2/970653'),
#  (110,
#   'sjsj 원피스 /82사이즈/ 뷔스티에원피스/블랙',
#   datetime.date(2022, 5, 16),
#   'https://cafe.naver.com/parisienlook/3548671'),
#  (111,
#   '우일 인견 뷔스티에 원피스',
#   datetime.date(2022, 4, 22),
#   'https://cafe.naver.com/hotdealcommunity/1900071'),
#  (112,
#   '레오파드 뷔스티에원피스',
#   datetime.date(2022, 5, 13),
#   'https://cafe.naver.com/kidsinlove/1021924'),
#  (113,
#   '롱 원피스 뷔스티에 원피스',
#   datetime.date(2022, 4, 14),
#   'https://cafe.naver.com/gloseems1/708594'),
#  (114,
#   '빈티지 슬립 뷔스티에 원피스',
#   datetime.date(2022, 5, 24),
#   'https://cafe.naver.com/tictoc/3013615'),
#  (115,
#   '뷔스티에 리본 원피스 팝니다',
#   datetime.date(2022, 5, 12),
#   'https://cafe.naver.com/cosmania/34622518'),
#  (116,
#   '뷔스티에 원피스,예쁜 상의 구해요!!',
#   datetime.date(2022, 3, 18),
#   'https://cafe.naver.com/ro11ypop/4156720'),
#  (117,
#   '브랜드 로엠 데님 뷔스티에 원피스 판매',
#   datetime.date(2022, 5, 13),
#   'https://cafe.naver.com/cosmania/34626239'),
#  (118,
#   '디라벨 챠밍 뷔스티에 원피스 크림',
#   datetime.date(2022, 4, 25),
#   'https://cafe.naver.com/imsanbu/60621325'),
#  (119,
#   '리리앤코 뷔스티에 원피스',
#   datetime.date(2021, 11, 8),
#   'https://cafe.naver.com/bigcc/349878'),
#  (120,
#   '새상품 메이빈스 뷔스티에 원피스 운포2',
#   datetime.date(2022, 5, 17),
#   'https://cafe.naver.com/cosmania/34648235'),
#  (121,
#   '플라워뷔스티에원피스❤여름에 요만한아이가 없쥬~',
#   datetime.date(2022, 5, 1),
#   'https://cafe.naver.com/hotdealcommunity/1913150'),
#  (122,
#   '디스커버리 남자 롱패딩 레스터G 이것이 대장이다',
#   datetime.date(2021, 12, 15),
#   'https://blog.naver.com/qjahsxm33/222596201207'),
#  (123,
#   '디스커버리 레스터 G 여성 롱패딩 가벼운 겨울 아우터!',
#   datetime.date(2021, 11, 29),
#   'https://blog.naver.com/jeongwon84/222582289659'),
#  (124,
#   '디스커버리 롱패딩 남자 겨울 코디 8할은 레스터G 구스다운★ ☃︎',
#   datetime.date(2021, 12, 23),
#   'https://blog.naver.com/hanbitnuri/222603089817'),
#  (125,
#   '라희 데일리룩 : 한파엔 역시 롱패딩이지!',
#   datetime.date(2022, 1, 12),
#   'https://blog.naver.com/powerppodea/222619859067'),
#  (126,
#   '쿠팡패션 휠라 키즈 운동화 롱패딩 하루만에 도착',
#   datetime.date(2021, 12, 9),
#   'https://blog.naver.com/ssdria/222590510780'),
#  (127,
#   '한파도 거뜬! 연말 패션을 완성시켜 줄 롱패딩 5',
#   datetime.date(2021, 12, 23),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=32998818&amp;memberNo=42835253&amp;vType=VERTICAL'),
#  (128,
#   '남자 롱패딩 디스커버리 레스터G 겨울 코디 가뿐하죠',
#   datetime.date(2022, 1, 3),
#   'https://blog.naver.com/limwuzzy88/222607504774'),
#  (129,
#   '롱패딩 물세탁 이제 필요없네요?',
#   datetime.date(2022, 5, 12),
#   'https://cafe.naver.com/15668981/4325345'),
#  (130,
#   '내셔널지오그래픽 롱패딩 카이만 사이즈 및 리뷰',
#   datetime.date(2021, 11, 29),
#   'https://blog.naver.com/yszin/222581076235'),
#  (131,
#   '이불장 그리고 롱패딩',
#   datetime.date(2022, 5, 2),
#   'https://cafe.naver.com/simpleliving/291244'),
#  (132,
#   '남자 롱패딩 이도현이 착용한 커버낫 어때요',
#   datetime.date(2021, 11, 25),
#   'https://blog.naver.com/leesin8888/222578432283'),
#  (133,
#   '롱패딩 물세탁 이게 답이네요?',
#   datetime.date(2022, 4, 4),
#   'https://cafe.naver.com/masanmam/5981634'),
#  (134,
#   'k2 씬에어 수지 여자 롱패딩 찐리뷰 (구스다운 ver)',
#   datetime.date(2021, 11, 6),
#   'https://blog.naver.com/jayuyu/222560053378'),
#  (135,
#   '케네스콜 롱패딩 카키 S / 블랙 XS',
#   datetime.date(2022, 3, 24),
#   'https://cafe.naver.com/ttoksun2/3881521'),
#  (136,
#   '주니어 롱패딩 디스커버리 키즈 에센셜 롱다운 깔끔해',
#   datetime.date(2022, 1, 11),
#   'https://blog.naver.com/dlstj0430/222619171982'),
#  (137,
#   '디스커버리 남자 롱패딩 레스터G로 겨울 코디 완성!',
#   datetime.date(2022, 1, 9),
#   'https://blog.naver.com/viper6262/222617085325'),
#  (138,
#   '여자패딩추천 코오롱스포츠 스노우문 공효진 롱패딩 ♥',
#   datetime.date(2021, 12, 18),
#   'https://blog.naver.com/dohyemm/222598345230'),
#  (139,
#   '디스커버리 남자 롱패딩 레스터G 구스다운 역시나 만족!',
#   datetime.date(2022, 1, 3),
#   'https://blog.naver.com/coolps8/222611639759'),
#  (140,
#   '오버핏 여자 롱패딩 추천 데일리 겨울코디 완성템 커버낫!',
#   datetime.date(2021, 12, 26),
#   'https://blog.naver.com/juhye__/222605071309'),
#  (141,
#   '몬데타 덕다운 롱패딩 폭탄세일 49800원 바로배송',
#   datetime.date(2022, 4, 27),
#   'https://cafe.naver.com/mompl/554250'),
#  (142,
#   '/마감/[아맹]*배송 2주 소요 / 따뜻하고 고급스러운 롱패딩을 착한 가격에 오픈합니다❤️',
#   datetime.date(2022, 1, 10),
#   'https://blog.naver.com/aminihoney/222618104041'),
#  (143,
#   'MLB 키즈 롱패딩 145',
#   datetime.date(2022, 3, 31),
#   'https://cafe.naver.com/hotdealcommunity/1867257'),
#  (144,
#   '국내완판 몽클레어 에리시멈 롱패딩 Erysimum 90만원 할인! 마이테레사 독일 직구',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/laughinglady/222600007317'),
#  (145,
#   '아키클래식 김남윤 화보 패션! 커플 숏패딩 브랜드 & 롱패딩 코디 추천',
#   datetime.date(2021, 11, 9),
#   'https://blog.naver.com/marieeeee_/222562869218'),
#  (146,
#   '롱패딩 세탁 쉽고 간편하게 가능?',
#   datetime.date(2022, 3, 2),
#   'https://cafe.naver.com/culturebloom/1512105'),
#  (147,
#   '내셔널지오그래픽 롱패딩 카이만으로 한파 대비 완료',
#   datetime.date(2021, 11, 28),
#   'https://blog.naver.com/yynopen/222581243669'),
#  (148,
#   '볼컴 남자 롱패딩 겨울 아우터 이젠 필수죠',
#   datetime.date(2021, 11, 25),
#   'https://blog.naver.com/95ert/222577857344'),
#  (149,
#   '띠어리 아울렛 롱패딩, 푸퍼 베스트 직구 면세안 + $25 코드!',
#   datetime.date(2022, 3, 5),
#   'https://blog.naver.com/jiny_home/222664218411'),
#  (150,
#   '여자 연예인 롱패딩 패션 다양한 브랜드 예쁘게 입어요',
#   datetime.date(2022, 1, 26),
#   'https://blog.naver.com/oddangzzigae/222632227566'),
#  (151,
#   '롱패딩 브랜드 빈트릴 윈터실드 다운 & 캔디 숏 비니로 겨울 코디 완성',
#   datetime.date(2021, 12, 1),
#   'https://blog.naver.com/jej7634/222584359832'),
#  (152,
#   '디스커버리 패딩 레스터 G 롱패딩, 프리미엄 여성 겨울 아우터♥',
#   datetime.date(2021, 11, 30),
#   'https://blog.naver.com/hug387/222583320460'),
#  (153,
#   '디스커버리 여성 롱패딩 겨울코디 따뜻하게!',
#   datetime.date(2021, 12, 15),
#   'https://blog.naver.com/vita_c1000/222595870031'),
#  (154,
#   '디스커버리 여성 롱패딩 레스터 G로 따뜻한 겨울코디',
#   datetime.date(2022, 1, 17),
#   'https://blog.naver.com/frenchpopp/222624038192'),
#  (155,
#   '*특가세일* 후드 퍼 패딩코트, 롱패딩, 밍크 퍼코트 프리오더 페이지에요!',
#   datetime.date(2022, 1, 23),
#   'https://blog.naver.com/wrusu/222629415316'),
#  (156,
#   '김희선 여자 명품 프리미엄 패딩 브랜드 페트레이 숏패딩, 롱패딩 까지! 겨울 코디 딱',
#   datetime.date(2021, 12, 26),
#   'https://blog.naver.com/zldnld99/222604688308'),
#  (157,
#   '디스커버리 남자 패딩 레스터G 롱패딩, 겨울 코디 필수!',
#   datetime.date(2022, 1, 1),
#   'https://blog.naver.com/wjsqjatn12/222610545065'),
#  (158,
#   '여성 롱패딩 브랜드 MLB 여자겨울아우터 미니멀룩까지',
#   datetime.date(2021, 12, 22),
#   'https://blog.naver.com/joaeng/222602095204'),
#  (159,
#   '여자 롱패딩 여성복 브랜드에서 찾기! 라인, 에고이스트, 쉬즈미스, 보브',
#   datetime.date(2021, 11, 20),
#   'https://blog.naver.com/purplemodern/222573812593'),
#  (160,
#   '남자겨울코디 추워지면 필수 아우터 내셔널지오그래픽 롱패딩 추천',
#   datetime.date(2021, 11, 28),
#   'https://blog.naver.com/kagama007/222579618110'),
#  (161,
#   '여자 롱패딩 추천, 르꼬끄 듀얼플렉스 롱다운으로 따뜻한 겨울 코디',
#   datetime.date(2021, 11, 17),
#   'https://blog.naver.com/jenny8428/222571337674'),
#  (162,
#   'MLB 여자 스니커즈 롱패딩과 함께 코디해봄',
#   datetime.date(2021, 12, 11),
#   'https://blog.naver.com/tjddk8860/222592487804'),
#  (163,
#   '이도현 여자 롱패딩 커버낫 롱패딩리뷰',
#   datetime.date(2021, 11, 14),
#   'https://blog.naver.com/gpgpaa92/222567375524'),
#  (164,
#   '디스커버리 패딩 레스터G 롱패딩 남자 구스다운 겨울 아우터로 추천!',
#   datetime.date(2021, 10, 24),
#   'https://blog.naver.com/rhksgn/222546534287'),
#  (165,
#   '널디 태연 롱패딩 따뜻한 여자 겨울아우터 맞네 맞아',
#   datetime.date(2021, 12, 9),
#   'https://blog.naver.com/minju1004b/222588627397'),
#  (166,
#   '올 겨울은 너로 정했닷! 널디 롱패딩 으뜨거따시!',
#   datetime.date(2021, 12, 7),
#   'https://blog.naver.com/2jyani/222588636006'),
#  (167,
#   '엄마는 아이돌 선예 옷 패션 무스너클 윌스턴 파카 여성 화이트 롱패딩 찾는다면!',
#   datetime.date(2022, 2, 4),
#   'https://blog.naver.com/sasa9508/222638403438'),
#  (168,
#   '오버핏 패딩 추천, 커버낫 남자 롱패딩 걸치면 겨울코디 끝',
#   datetime.date(2021, 12, 18),
#   'https://blog.naver.com/2jin9u/222598335588'),
#  (169,
#   '디스커버리 레스터G 롱패딩, 겨울 코디로 추천 추천~!',
#   datetime.date(2022, 1, 18),
#   'https://blog.naver.com/namgungky/222624455678'),
#  (170,
#   'MLB 남성 여성패딩 데일리룩 롱패딩 점퍼 코디! 겨울 남자 여자아우터',
#   datetime.date(2022, 1, 3),
#   'https://blog.naver.com/hooshia/222611951740'),
#  (171,
#   '커버낫 x 이도현의 여자 롱패딩 블랙으로 따뜻!',
#   datetime.date(2021, 11, 26),
#   'https://blog.naver.com/sm1004ys/222578240063'),
#  (172,
#   "겨울 패딩 코디 '디스커버리 레스터G 롱패딩'",
#   datetime.date(2022, 1, 3),
#   'https://blog.naver.com/barim12/222611975603'),
#  (173,
#   '불량소년 OOTD LOOK BOOK(룩북)의 2022년 2월 3일 목요일 데일리룩(구스다운 롱패딩 아우터, 스웨터...',
#   datetime.date(2022, 2, 4),
#   'https://blog.naver.com/peopleteria/222638295394'),
#  (174,
#   '디스커버리 패딩으로 겨울아우터장만한다면? 여성 롱패딩은 아묻따 "레스터 G 롱패딩"',
#   datetime.date(2021, 11, 29),
#   'https://blog.naver.com/ea97/222582291563'),
#  (175,
#   '아직 추운데 다들 롱패딩 벗으셨네요',
#   datetime.date(2022, 3, 15),
#   'https://cafe.naver.com/workee/955623'),
#  (176,
#   '아키클래식 스걸파 YGX 이삭 숏패딩 / 정혁 롱패딩 둘 다 예쁘네♥ 추천 :)',
#   datetime.date(2022, 1, 8),
#   'https://blog.naver.com/rudelulu/222616399359'),
#  (177,
#   '메이시스에서 구입한 폴로걸즈 롱패딩 왔어요.',
#   datetime.date(2022, 3, 12),
#   'https://cafe.naver.com/smartbargain/1391203'),
#  (178,
#   '디스커버리 레스터 G 롱패딩 여자 롱패딩 겨울 아우터로 추천 !',
#   datetime.date(2021, 12, 19),
#   'https://blog.naver.com/hyujing/222599393655'),
#  (179,
#   '추울땐 여전히 롱패딩! 자라 패딩 & 팔로마울 아니타 니트 & 타입서비스 볼캡 모자 겨울 캐주얼 데일리룩',
#   datetime.date(2022, 1, 14),
#   'https://blog.naver.com/reeie80/222621878268'),
#  (180,
#   '롱패딩 세탁 진행하신 분??',
#   datetime.date(2022, 2, 24),
#   'https://cafe.naver.com/gloseems1/683585'),
#  (181,
#   '디스커버리 레스터 G 롱패딩 코디하기 좋은 겨울 아우터',
#   datetime.date(2021, 11, 30),
#   'https://blog.naver.com/sjejlove04/222583353027'),
#  (182,
#   '르꼬끄 듀얼플렉스 롱다운 겨울 코디 속 남자 롱패딩 추천!',
#   datetime.date(2021, 11, 22),
#   'https://blog.naver.com/berakol/222575305974'),
#  (183,
#   '여성 구스다운 디스커버리 레스터 G 롱패딩 가볍고 예쁘네요',
#   datetime.date(2021, 10, 28),
#   'https://blog.naver.com/yulee6640/222551558758'),
#  (184,
#   '디스커버리 레스터G 롱패딩 라이트베이지 겨울코디 완성!',
#   datetime.date(2022, 1, 2),
#   'https://blog.naver.com/thdud_/222610923619'),
#  (185,
#   '자라 롱패딩이랑 롱체크셔츠 왔어요(짝꿍)',
#   datetime.date(2022, 2, 27),
#   'https://cafe.naver.com/nyblog/1264675'),
#  (186,
#   'MLB 여자 롱패딩, 청키하이 운동화! 여성 아우터, 겨울신발 코디',
#   datetime.date(2021, 11, 15),
#   'https://blog.naver.com/blingnas/222569169778'),
#  (187,
#   '몸을 감싸는 포근함으로 겨울을 따뜻하게 만들어줄 여성 롱패딩',
#   datetime.date(2021, 12, 16),
#   'https://blog.naver.com/w_angle2014/222597046158'),
#  (188,
#   '롱패딩수선 여성롱패딩 수선잘하는곳 롱패딩 기장수선 롱패딩 어깨수선...',
#   datetime.date(2022, 2, 22),
#   'https://blog.naver.com/jy7094yj/222654960895'),
#  (189,
#   '몽클레어 여성 휴곤 롱패딩 블랙 1사이즈 / 반값세일',
#   datetime.date(2022, 5, 12),
#   'https://cafe.naver.com/ttoksun2/4058289'),
#  (190,
#   '여자 퀄팅 롱 패딩 양털 누빔 롱패딩 (3color)',
#   datetime.date(2021, 12, 2),
#   'https://blog.naver.com/soda1991/222584908512'),
#  (191,
#   '롱패딩 세탁법 만능템 하나로 해결~',
#   datetime.date(2021, 12, 31),
#   'https://cafe.naver.com/baby8/2270828'),
#  (192,
#   '디스커버리 여성 롱패딩 레스터G 구스다운으로 따뜻하게 겨울코디',
#   datetime.date(2022, 2, 12),
#   'https://blog.naver.com/tls0819/222645929176'),
#  (193,
#   '센스 스톤아일랜드 크링클랩스 롱패딩',
#   datetime.date(2021, 12, 26),
#   'https://cafe.naver.com/smartbargain/1343738'),
#  (194,
#   '(3건) 쟈딕후드/ 띠어리 롱패딩/ 르쿠르제 라메킨',
#   datetime.date(2022, 2, 23),
#   'https://cafe.naver.com/ttoksun2/3777782'),
#  (195,
#   '몽클레어 롱패딩 가디건 블랙 S',
#   datetime.date(2022, 3, 15),
#   'https://cafe.naver.com/ttoksun2/3847785'),
#  (196,
#   '파리 샹젤리제 몽클레어 매장에서 롱패딩 샀어요!!',
#   datetime.date(2022, 2, 13),
#   'https://cafe.naver.com/nyblog/1247808'),
#  (197,
#   '오샀없는 K2수지 롱패딩이 왔는데요….',
#   datetime.date(2021, 12, 15),
#   'https://cafe.naver.com/nyblog/1177355'),
#  (198,
#   '추울땐 롱패딩',
#   datetime.date(2021, 12, 26),
#   'https://cafe.naver.com/young08277/39541'),
#  (199,
#   '저만 롱패딩 입는거 같아요',
#   datetime.date(2022, 3, 25),
#   'https://cafe.naver.com/chengnamomlife/1796547'),
#  (200,
#   '띠어리 롱패딩 첫 후기입니다~~',
#   datetime.date(2022, 2, 24),
#   'https://cafe.naver.com/newyorkgirlz/1136787'),
#  (201,
#   '삭스 에르노 롱패딩 38사이즈',
#   datetime.date(2022, 3, 25),
#   'https://cafe.naver.com/nyblog/1295795'),
#  (204,
#   '롱패딩 색 고민 도와주세요',
#   datetime.date(2022, 1, 17),
#   'https://cafe.naver.com/nyblog/1215266'),
#  (205,
#   '가는겨울 끝자락에 롱패딩을 사봅니다.',
#   datetime.date(2022, 2, 9),
#   'https://cafe.naver.com/smartbargain/1370934'),
#  (206,
#   '겁나 따뜻한 롱패딩 뭐있나요??',
#   datetime.date(2021, 12, 13),
#   'https://cafe.naver.com/coredenim/846643'),
#  (207,
#   '롱패딩 보통 몇년 입으세요??',
#   datetime.date(2022, 5, 8),
#   'https://cafe.naver.com/cosmania/34600676'),
#  (208,
#   '9시 나인 악마 롱패딩 플레이트 상태',
#   datetime.date(2022, 3, 7),
#   'https://cafe.naver.com/2ndkalsuma/4139361'),
#  (209,
#   '두번입은 롱패딩 세탁하시나요?',
#   datetime.date(2022, 5, 4),
#   'https://cafe.naver.com/usem/1858443'),
#  (210,
#   '몽클레어 롱패딩 가디건',
#   datetime.date(2022, 5, 9),
#   'https://cafe.naver.com/ttoksun2/4048666'),
#  (211,
#   '몽클레어 coche 롱패딩(미세하자) 사이즈1',
#   datetime.date(2022, 4, 24),
#   'https://cafe.naver.com/ttoksun2/3994873'),
#  (212,
#   '몽클레어 롱패딩',
#   datetime.date(2022, 5, 24),
#   'https://cafe.naver.com/yjoutlet/3869734'),
#  (213,
#   '거래완료]로히드한남]여아 롱패딩 새제품',
#   datetime.date(2022, 5, 11),
#   'https://cafe.naver.com/yoehang/361683'),
#  (214,
#   '유아 롱패딩 조끼',
#   datetime.date(2022, 3, 29),
#   'https://cafe.naver.com/chobomamy/2163026'),
#  (215,
#   '롱패딩 백화점 새제품',
#   datetime.date(2022, 4, 17),
#   'https://cafe.naver.com/jinhaemam/1957981'),
#  (216,
#   '아이더 롱패딩 120사이즈',
#   datetime.date(2022, 2, 2),
#   'https://cafe.naver.com/kyungmammo/5518424'),
#  (217,
#   '140사이즈 오리털 롱패딩',
#   datetime.date(2022, 4, 19),
#   'https://cafe.naver.com/byungs94/6991753'),
#  (218,
#   '롱패딩 사이즈(55~77까지)',
#   datetime.date(2022, 5, 24),
#   'https://cafe.naver.com/cosmania/34677807'),
#  (219,
#   '랩 롱패딩',
#   datetime.date(2022, 3, 2),
#   'https://cafe.naver.com/byungs94/6943068'),
#  (220,
#   '파타고니아 경량 롱패딩',
#   datetime.date(2022, 2, 28),
#   'https://cafe.naver.com/kockoc11/2550450'),
#  (221,
#   '롱패딩 압축팩',
#   datetime.date(2022, 5, 9),
#   'https://cafe.naver.com/usem/1861175'),
#  (222,
#   '남자 숏패딩 브랜드 캘빈클라인 진 CK',
#   datetime.date(2021, 11, 24),
#   'https://blog.naver.com/darigile/222577621971'),
#  (223,
#   '퀼팅 여성 숏패딩 추천 브랜드 GGPX!',
#   datetime.date(2022, 1, 27),
#   'https://blog.naver.com/kesook02/222633222360'),
#  (224,
#   '에피그램 남자 숏패딩, 양털카라가 매력적이네요!',
#   datetime.date(2021, 11, 22),
#   'https://blog.naver.com/viper6262/222575368684'),
#  (225,
#   '디아도라 패딩 프리즈 숏패딩 리뷰 in 롯데백화점 평촌점',
#   datetime.date(2021, 11, 13),
#   'https://blog.naver.com/yszin/222566456243'),
#  (226,
#   '숏자켓, 숏패딩 등 숏아우터 코디하기',
#   datetime.date(2021, 11, 20),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=32783194&amp;memberNo=15964145&amp;vType=VERTICAL'),
#  (227,
#   '꾸안꾸 룩에 입기 좋은 여자 웰론 숏패딩 추천',
#   datetime.date(2022, 1, 24),
#   'https://blog.naver.com/juhye__/222630182317'),
#  (228,
#   '남자 숏패딩 브랜드 골스튜디오 써클 엠보 패딩 유니크해',
#   datetime.date(2021, 12, 4),
#   'https://blog.naver.com/limwuzzy88/222585890200'),
#  (229,
#   '얼죽코? 이제는 얼죽숏! ★얼어죽어도 숏패딩★ 스타일링 추천',
#   datetime.date(2022, 1, 3),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=33056808&amp;memberNo=1097200&amp;vType=VERTICAL'),
#  (230,
#   '띠어리 버터 숏패딩 저도 탑승...!',
#   datetime.date(2022, 3, 21),
#   'https://cafe.naver.com/nyblog/1289388'),
#  (231,
#   '남성 숏패딩 플랙 리버시블 양면으로 즐겨요',
#   datetime.date(2021, 12, 13),
#   'https://blog.naver.com/qjahsxm33/222594481447'),
#  (232,
#   '30대 여자쇼핑몰 하프클럽 더아이잗뉴욕 숏패딩 점퍼 예쁜 겨울옷 겟',
#   datetime.date(2022, 1, 21),
#   'https://blog.naver.com/minimouse24/222627855174'),
#  (233,
#   '노스페이스 여자 숏패딩 다운 + 플리스 자켓 찐리뷰 & 추천',
#   datetime.date(2021, 12, 28),
#   'https://blog.naver.com/jayuyu/222606571736'),
#  (234,
#   '아소스 숏패딩 저도 샀어요',
#   datetime.date(2022, 5, 16),
#   'https://cafe.naver.com/smartbargain/1425154'),
#  (235,
#   '남자 숏패딩 추천 오닐 하이드 다운 패딩 귀엽네요',
#   datetime.date(2021, 12, 22),
#   'https://blog.naver.com/2jin9u/222601554449'),
#  (236,
#   '시고르경양식 최지우패딩, 노란패딩은 드니벨 에어락 숏패딩!',
#   datetime.date(2022, 1, 16),
#   'https://blog.naver.com/sooooong2/222623283638'),
#  (237,
#   '남자 숏패딩 코디 덕다운 부터 1+1 까지 가성비 아이템으로 준비완료!',
#   datetime.date(2021, 12, 25),
#   'https://blog.naver.com/coolps8/222604423679'),
#  (238,
#   '키즈 여아 숏패딩 주니어 착샷 디스커버리 리버시블 블랙 ~',
#   datetime.date(2021, 12, 12),
#   'https://blog.naver.com/gentle0293/222593665312'),
#  (239,
#   '오늘은 온앤온에서 예쁜 숏패딩을 찾아 봅니다.',
#   datetime.date(2022, 1, 13),
#   'https://cafe.naver.com/famsale/2500324'),
#  (240,
#   '플랙 리버시블 패딩 활용도 높은 남자 숏패딩 추천',
#   datetime.date(2021, 12, 14),
#   'https://blog.naver.com/95ert/222595661008'),
#  (241,
#   '플랙 리버시블 패딩 이유 있는 여성 숏패딩 추천',
#   datetime.date(2021, 12, 13),
#   'https://blog.naver.com/dohyemm/222593934759'),
#  (242,
#   '그레이 숏패딩 하나 사려고하는데요!',
#   datetime.date(2021, 12, 27),
#   'https://cafe.naver.com/zzang9daddy/775084'),
#  (243,
#   '숏패딩 괜찮은거 있을까요?',
#   datetime.date(2021, 12, 25),
#   'https://cafe.naver.com/casuallydressed/433658'),
#  (244,
#   '[넌블랭크] - 캐주얼한 느낌 물씬 나버리네~~~ / 후드 숏패딩 라이트 베이지 손태양 후기',
#   datetime.date(2022, 4, 22),
#   'https://cafe.naver.com/dieselmania/37972162'),
#  (245,
#   '오닐 여성 숏패딩, 하이드 다운점퍼 힙하다!',
#   datetime.date(2021, 12, 22),
#   'https://blog.naver.com/ltellmel/222601412033'),
#  (246,
#   '스파오 숏패딩 여성 파스텔 푸퍼 너로 정했어',
#   datetime.date(2021, 11, 29),
#   'https://blog.naver.com/ssdria/222581350263'),
#  (247,
#   '정호연, 앨리스펑크 숏패딩 브랜드 캘빈클라인 진 여성 패딩, CK 공홈 할인코드도 공유해요 + +',
#   datetime.date(2021, 11, 19),
#   'https://blog.naver.com/llmement/222572557169'),
#  (248,
#   '띠어리 숏패딩 왔어요',
#   datetime.date(2022, 3, 8),
#   'https://cafe.naver.com/smartbargain/1389149'),
#  (249,
#   'moodndress (SALE) 겨울세일 덕다운100%숏패딩 오리털패딩 여성패딩 다운패딩 겨울코디',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/moodndress/222599910389'),
#  (250,
#   '스트레치엔젤스 여자 겨울코디는 나만의 숏패딩 추천',
#   datetime.date(2021, 12, 8),
#   'https://blog.naver.com/minju1004b/222590025061'),
#  (251,
#   '숏패딩 코디 뉴발란스 액티브다운으로 심플하게',
#   datetime.date(2021, 11, 5),
#   'https://blog.naver.com/leesin8888/222559677758'),
#  (252,
#   '디스커버리 여성 숏패딩 레스터G RDS 구스다운 마운틴쿡 사이즈!',
#   datetime.date(2021, 12, 2),
#   'https://blog.naver.com/hug387/222585271935'),
#  (253,
#   '쿨트 숏패딩, 파우치 귀엽게 코디하기 좋아요!',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/vita_c1000/222599736931'),
#  (254,
#   '여성 패딩 오닐 하이드 다운점퍼 숏패딩이지',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/tjdbs0323/222597602344'),
#  (255,
#   '[준지] 준지 169 구스 숏패딩 후기 착샷',
#   datetime.date(2021, 12, 26),
#   'https://cafe.naver.com/coredenim/865702'),
#  (256,
#   '올리비아로렌 숏패딩 30대 여자쇼핑몰 하프클럽에서 겟',
#   datetime.date(2022, 2, 10),
#   'https://blog.naver.com/sjejlove04/222643511639'),
#  (257,
#   'mlb숏패딩',
#   datetime.date(2022, 3, 13),
#   'https://cafe.naver.com/ttoksun2/3841633'),
#  (258,
#   '1st winter market) 프리미엄 퀼팅 숏패딩, 경량패딩 (누빔) OPEN!',
#   datetime.date(2021, 10, 31),
#   'https://blog.naver.com/wrusu/222554495155'),
#  (259,
#   '스파오 파스텔 푸퍼 숏패딩 /코듀로이 숏패딩',
#   datetime.date(2022, 2, 9),
#   'https://blog.naver.com/milk916/222643234739'),
#  (260,
#   '뉴발란스 숏패딩 액티브다운 색감에 반해버렸당',
#   datetime.date(2021, 12, 7),
#   'https://blog.naver.com/jin2daeyoon/222588547910'),
#  (261,
#   '플랙 리버시블 패딩 남자 숏패딩 추천 드립니다.',
#   datetime.date(2021, 12, 14),
#   'https://blog.naver.com/wjsqjatn12/222595184922'),
#  (262,
#   '남자 숏패딩 지프 겨울 데일리룩 완성!',
#   datetime.date(2021, 12, 9),
#   'https://blog.naver.com/rhksgn/222591460308'),
#  (263,
#   '몽클레어 숏패딩 DON(22)',
#   datetime.date(2022, 1, 24),
#   'https://cafe.naver.com/ttoksun2/3673408'),
#  (264,
#   '오닐 윌로우 코듀로이 남자 숏패딩 이거 완전 매력 넘침~!',
#   datetime.date(2021, 12, 22),
#   'https://blog.naver.com/namgungky/222601564360'),
#  (265,
#   '볼컴 옐로우 여자 숏패딩 기분전환용 다운점퍼!',
#   datetime.date(2021, 10, 31),
#   'https://blog.naver.com/yynopen/222554597470'),
#  (266,
#   '시고르경양식 최지우 노란패딩 드니벨 숏패딩',
#   datetime.date(2022, 1, 14),
#   'https://blog.naver.com/k_159500/222621662491'),
#  (267,
#   '존예 화이트 숏패딩 찾음! 유이 차정원도 입은 루에브르 패딩 ♥',
#   datetime.date(2021, 12, 14),
#   'https://blog.naver.com/2jyani/222594412264'),
#  (268,
#   '김나영 롱패딩 듀베티카 알바르다 & 이세영 숏패딩 디아데마! 여자 명품 프리미엄 패딩 브랜드',
#   datetime.date(2021, 12, 29),
#   'https://blog.naver.com/marieeeee_/222607939748'),
#  (269,
#   '제니 화보 패션 속 매력적인 여자 숏패딩 맨투맨 브랜드 캘빈클라인 진, 언더웨어',
#   datetime.date(2021, 12, 12),
#   'https://blog.naver.com/purplemodern/222593438204'),
#  (270,
#   '아키클래식 롱패딩 한파전에 챙겨봐 스걸파 YGX 이삭 숏패딩도 추천',
#   datetime.date(2022, 1, 9),
#   'https://blog.naver.com/frenchpopp/222617151805'),
#  (271,
#   '키큰여자쇼핑몰 숏패딩 귀엽잖아 !',
#   datetime.date(2022, 1, 24),
#   'https://blog.naver.com/luci_yaaa/222629715253'),
#  (272,
#   '아키클래식 스걸파 YGX 이삭 숏패딩 / 정혁 롱패딩 둘 다 예쁘네♥ 추천 :)',
#   datetime.date(2022, 1, 8),
#   'https://blog.naver.com/rudelulu/222616399359'),
#  (273,
#   '겨울 패딩 , 숏패딩',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/yny77777/222600300651'),
#  (274,
#   '마크엠 숏패딩 포근한 겨울아우터 여자 덕다운 점퍼 귀여워 #markm',
#   datetime.date(2021, 12, 29),
#   'https://blog.naver.com/oldpopsong/222606246053'),
#  (275,
#   '한눈에 반한 디스커버리 숏패딩 샀으요.',
#   datetime.date(2022, 1, 30),
#   'https://cafe.naver.com/nyblog/1231098'),
#  (276,
#   '여성 숏패딩 디스커버리 패딩 마운틴쿡으로 겨울 코디 끝',
#   datetime.date(2021, 12, 12),
#   'https://blog.naver.com/yulee6640/222593784465'),
#  (277,
#   '트레이닝 브랜드 아키클래식 여성 숏패딩 추천!',
#   datetime.date(2021, 11, 26),
#   'https://blog.naver.com/jeongwon84/222579120040'),
#  (278,
#   '내 옷 : 겨울 아우터 / 코트, 숏패딩 편',
#   datetime.date(2022, 3, 14),
#   'https://blog.naver.com/sadbuttrue81/222671972083'),
#  (279,
#   '여자 숏패딩 웰론으로 털 빠짐없이 가볍게!',
#   datetime.date(2021, 12, 14),
#   'https://blog.naver.com/dbsqhr223/222595415778'),
#  (280,
#   'PLAC 플랙 숏패딩 추천, 리버시블 패딩 윈터세일 할인해요',
#   datetime.date(2021, 12, 9),
#   'https://blog.naver.com/blingnas/222591078971'),
#  (281,
#   '엔시티 NCT 태일 인스타그램 옷은 빈트릴 숏패딩',
#   datetime.date(2021, 12, 3),
#   'https://blog.naver.com/pppmh0827/222585474148'),
#  (282,
#   '남자 숏패딩 앤듀 (ANDEW) 패딩입고 겨울코디 완성!',
#   datetime.date(2021, 12, 3),
#   'https://blog.naver.com/berakol/222585806028'),
#  (283,
#   '[GUESS] 게스 숏패딩 스타일링 팁',
#   datetime.date(2021, 12, 14),
#   'https://blog.naver.com/guess_korea/222594442225'),
#  (284,
#   '제주도 3월 날씨 숏패딩 가능할까요?',
#   datetime.date(2022, 2, 20),
#   'https://cafe.naver.com/casuallydressed/450168'),
#  (285,
#   '프라다 숏패딩 vs 몽클 카르돈셀 고민돼요 ㅠㅠㅠ골라주세요..',
#   datetime.date(2021, 12, 20),
#   'https://cafe.naver.com/parisienlook/3192844'),
#  (286,
#   '4세남아. 롱패딩vs숏패딩',
#   datetime.date(2021, 11, 24),
#   'https://cafe.naver.com/imsanbu/58382125'),
#  (287,
#   '광택감 있는 아이보리 숏패딩',
#   datetime.date(2021, 12, 14),
#   'https://cafe.naver.com/casuallydressed/430643'),
#  (288,
#   '아미 그레이 오버사이즈 숏패딩 m/l구해주세요',
#   datetime.date(2022, 4, 6),
#   'https://cafe.naver.com/ttoksun2/3929142'),
#  (289,
#   '몽클레어 숏패딩 추천해 주세요',
#   datetime.date(2022, 1, 15),
#   'https://cafe.naver.com/smartbargain/1356492'),
#  (290,
#   '초5 딸램 숏패딩 추천해주세요',
#   datetime.date(2021, 12, 6),
#   'https://cafe.naver.com/malltail/6290655'),
#  (291,
#   '숏패딩',
#   datetime.date(2021, 12, 6),
#   'https://cafe.naver.com/gloseems1/639949'),
#  (292,
#   '아미 그레이 오버사이즈 숏패딩 100사이즈',
#   datetime.date(2022, 4, 6),
#   'https://cafe.naver.com/kockoc11/2605589'),
#  (293,
#   '커스텀멜로우 숏패딩 사라마라',
#   datetime.date(2021, 11, 12),
#   'https://cafe.naver.com/dieselmania/36468010'),
#  (294,
#   '나이키 공홈에서 숏패딩 충동구매',
#   datetime.date(2021, 12, 30),
#   'https://cafe.naver.com/nyblog/1196312'),
#  (295,
#   '띠어리 푸퍼 숏패딩 샀어요',
#   datetime.date(2022, 2, 16),
#   'https://cafe.naver.com/smartbargain/1376635'),
#  (296,
#   '바쏘 숏패딩 / +J 워크팬츠',
#   datetime.date(2021, 12, 25),
#   'https://cafe.naver.com/dieselmania/36849368'),
#  (297,
#   '블랙야크 다운 숏패딩 핑크 95사이즈',
#   datetime.date(2022, 3, 6),
#   'https://cafe.naver.com/kyungmammo/5561821'),
#  (298,
#   '디스커버리 숏패딩',
#   datetime.date(2022, 5, 12),
#   'https://cafe.naver.com/byungs94/7012264'),
#  (299,
#   '프라다 여성 구스다운 숏패딩 새상품',
#   datetime.date(2022, 5, 8),
#   'https://cafe.naver.com/ttoksun2/4044748'),
#  (300,
#   '주크 트위드 베이지 숏패딩',
#   datetime.date(2022, 4, 24),
#   'https://cafe.naver.com/handsomebubble/424352'),
#  (301,
#   '극소량/허그패딩/와샤원단 숏패딩 초고퀄',
#   datetime.date(2022, 3, 8),
#   'https://cafe.naver.com/shopjirmsin/6950256'),
#  (302,
#   '발리 숏패딩',
#   datetime.date(2021, 12, 2),
#   'https://cafe.naver.com/ttoksun2/3491181'),
#  (303,
#   '프라다 여성 숏패딩',
#   datetime.date(2022, 2, 15),
#   'https://cafe.naver.com/kockoc11/2531716'),
#  (304,
#   '프라다 숏패딩',
#   datetime.date(2022, 3, 16),
#   'https://cafe.naver.com/parisienlook/3415382'),
#  (305,
#   '디스커버리 숏패딩',
#   datetime.date(2021, 12, 29),
#   'https://cafe.naver.com/imsanbu/58866204'),
#  (306,
#   '내셔널지오그래픽 숏패딩 블랙 115',
#   datetime.date(2022, 2, 12),
#   'https://cafe.naver.com/daechonmom/305397'),
#  (307,
#   '남자 롱코트 오버핏 1초 완판템 입어보기',
#   datetime.date(2022, 1, 11),
#   'https://blog.naver.com/darigile/222619000366'),
#  (308,
#   '루에브르 레디투웨어 겨울 롱코트 코디 두가지 ! 더블 코트',
#   datetime.date(2022, 1, 5),
#   'https://blog.naver.com/iamheozzang/222613231928'),
#  (309,
#   '[디자이너브랜드] 다가오는 겨울을 대비한 롱코트 추천(킨더살몬/던스트/ 다이애그널)',
#   datetime.date(2021, 10, 22),
#   'https://blog.naver.com/ssi_000/222544669080'),
#  (310,
#   '여성 코트 세인트제임스 봄 롱코트 코디로 세련미 더하기!',
#   datetime.date(2022, 4, 2),
#   'https://blog.naver.com/soeyoung1004/222689566347'),
#  (311,
#   '신사와아가씨 박하나 코트 패션 속 여자 겨울 롱코트 베스띠벨리 데일리웨어죠',
#   datetime.date(2022, 1, 13),
#   'https://blog.naver.com/zldnld99/222620660951'),
#  (312,
#   '툭 걸치면 끝! 셀럽 롱코트 데일리룩 6',
#   datetime.date(2021, 11, 23),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=32803487&amp;memberNo=12504201&amp;vType=VERTICAL'),
#  (313,
#   '딘디 데일리룩 - 마조네 하이 울 롱코트, 핑크 슬랙스, 구찌 가방(크로스백), 르바 니트, 그란사소 캐시미어...',
#   datetime.date(2021, 11, 26),
#   'https://blog.naver.com/tlswlgprjt/222578913040'),
#  (314,
#   '캐시미어 100% 롱코트 패션, 차분한 여성 겨울 코디에 센존 블루라벨',
#   datetime.date(2021, 10, 30),
#   'https://blog.naver.com/frenchpopp/222553684878'),
#  (315,
#   'DEPT.ANONYM(뎁트 애너님) 직구 남자 롱코트, 여자 터틀넥 리뷰',
#   datetime.date(2021, 12, 31),
#   'https://blog.naver.com/wjsqjatn12/222608964930'),
#  (679,
#   '홈웨어 어떤거 입으세요?(추천있음)',
#   datetime.date(2022, 5, 15),
#   'https://cafe.naver.com/japanmama/656486'),
#  (316,
#   '남자 롱코트 트렌디 하고 넉넉한 오버핏 스타일',
#   datetime.date(2021, 12, 18),
#   'https://blog.naver.com/qjahsxm33/222598656621'),
#  (317,
#   '남자밍크 롱코트 연말특가 이벤트 - 화려한 패션 스타일의 후드폭스 블랙그라마 롱밍크',
#   datetime.date(2021, 12, 23),
#   'https://blog.naver.com/furdaedong/222603044377'),
#  (318,
#   '별똥별 이성경 오한별 롱코트 패션 @벤시몽',
#   datetime.date(2022, 5, 20),
#   'https://cafe.naver.com/cosmania/34661327'),
#  (319,
#   '신사와 아가씨 이세희 패션 코트 박단단 옷 라인어디션 여성 롱코트 오피스룩 추천',
#   datetime.date(2022, 3, 29),
#   'https://blog.naver.com/sh_theme/222686288782'),
#  (320,
#   '[쿠어] 퀄리티와 CS에 크게 실망한 후기. (울 블루종, 트렌치 코트, 더블 롱코트)',
#   datetime.date(2022, 4, 19),
#   'https://cafe.naver.com/coredenim/1008355'),
#  (321,
#   '롱코트 키가작아서 정강이 절반 아래로 오는데 이거 오반가요..?',
#   datetime.date(2022, 5, 18),
#   'https://cafe.naver.com/coredenim/1040986'),
#  (322,
#   '리이 rerhee 겨울 코트 (노제 롱코트) 실물 찐리뷰',
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/jayuyu/222600127309'),
#  (323,
#   '테디베어 롱코트',
#   datetime.date(2022, 3, 31),
#   'https://cafe.naver.com/ttoksun2/3905982'),
#  (324,
#   '우아한 롱코트 추천! 포레드센느 여자 핸드메이드 코트 관리법까지',
#   datetime.date(2021, 11, 13),
#   'https://blog.naver.com/juhye__/222567028646'),
#  (325,
#   '네이비 모직 롱코트 12,000원',
#   datetime.date(2022, 5, 15),
#   'https://cafe.naver.com/planatic/7379363'),
#  (326,
#   '여성 롱코트 더블과 싱글 나에게 어울리는 코트는?',
#   datetime.date(2021, 12, 22),
#   'https://blog.naver.com/dbsqhr223/222602055776'),
#  (327,
#   '신사와 아가씨 박하나 샤틴 스웨이드 퀼팅 롱코트 완판될만해',
#   datetime.date(2021, 12, 6),
#   'https://blog.naver.com/mirang1227/222587730503'),
#  (328,
#   '여성겨울코트 에일라 Ayra 롱코트로 겨울코디',
#   datetime.date(2022, 1, 11),
#   'https://blog.naver.com/jenny8428/222618969976'),
#  (329,
#   '고현정 패션! 보그에서 착용한 로에베 여자 롱코트 추천 & 명품 가방 퍼즐백 핸드백',
#   datetime.date(2021, 11, 30),
#   'https://blog.naver.com/purplemodern/222582658624'),
#  (330,
#   '여자 롱코트, 한겨울에도 따뜻한 데일리룩 에일라',
#   datetime.date(2021, 12, 31),
#   'https://blog.naver.com/ltellmel/222609491551'),
#  (331,
#   '마랑 퍼 롱코트 외',
#   datetime.date(2022, 3, 21),
#   'https://cafe.naver.com/ttoksun2/3869078'),
#  (332,
#   '반달호보 숄더백. 보드 체크앙상블가디건. 레더 포켓팬츠. 언발 머드부츠. 모헤어 핸드메이드 롱코트',
#   datetime.date(2021, 10, 20),
#   'https://blog.naver.com/mani0005/222542686345'),
#  (333,
#   'SALE) 숄카라 핸드메이드 코트, 롱코트 2컬러 선착순 원가세일 진행해요!',
#   datetime.date(2021, 12, 26),
#   'https://blog.naver.com/wrusu/222605259458'),
#  (334,
#   '삼양모피/리가 2차(머플러), 롱코트 왔어요~',
#   datetime.date(2022, 1, 26),
#   'https://cafe.naver.com/famsale/2505886'),
#  (335,
#   '롱코트 기장수선 - 창원맞춤정장 창원맞춤예복 제나비테일러 창원점',
#   datetime.date(2022, 2, 8),
#   'https://blog.naver.com/xlddlxlddl/222642542700'),
#  (336,
#   '세이노모어 겨울셋업부터 오버사이즈 롱코트까지 완벽해',
#   datetime.date(2021, 11, 15),
#   'https://blog.naver.com/sweetjhye/222568983784'),
#  (337,
#   '[0113] 부클 롱코트(마지막 아우터)',
#   datetime.date(2022, 1, 13),
#   'https://blog.naver.com/eeber/222620915303'),
#  (338,
#   '막스마라 박싱데이 파르마 롱코트, 비스터빌리지 아울렛 핫딜',
#   datetime.date(2021, 12, 27),
#   'https://blog.naver.com/lovelyjw05/222606056567'),
#  (339,
#   '여자 레더 트렌치 코트, 인조 가죽 롱코트',
#   datetime.date(2021, 10, 19),
#   'https://blog.naver.com/amour1202/222542156537'),
#  (340,
#   '여자 무스탕 양가죽 코디 - 여성 무스탕 시어링 자켓, 조끼, 롱코트 패션 코디 추천',
#   datetime.date(2021, 11, 2),
#   'https://blog.naver.com/syous0/222555805687'),
#  (341,
#   '센존 블루라벨 캐시미어 100% 롱코트, 고급스러운 여성 겨울 코디',
#   datetime.date(2021, 10, 30),
#   'https://blog.naver.com/llmement/222553271018'),
#  (342,
#   'JJ지고트 혜리 핸드메이드 숏코트, 롱코트, 구스 패딩 전부 예뻐♥ 여자 겨울 옷 추천!',
#   datetime.date(2021, 11, 8),
#   'https://blog.naver.com/rudelulu/222562406491'),
#  (343,
#   '남자 코트 코디 벨리에 캐시미어 롱코트 간지난다...',
#   datetime.date(2021, 11, 10),
#   'https://blog.naver.com/hoggiii/222562392787'),
#  (344,
#   '겨울셋업 세이노모어 겨울자켓 더플숏코트 오버사이즈 롱코트 기대되요',
#   datetime.date(2021, 11, 8),
#   'https://blog.naver.com/mhsi0501/222561633082'),
#  (345,
#   '알파카디올코트 / 핸드메이드 롱코트 / 카멜코트',
#   datetime.date(2021, 12, 15),
#   'https://blog.naver.com/wusl2524/222595897392'),
#  (346,
#   '키작은 남자 롱코트 코디 어렵지 않아요! 입어보시죠!',
#   datetime.date(2022, 1, 11),
#   'https://blog.naver.com/usedfashion/222619162846'),
#  (347,
#   '2021 겨울 여자 롱코트 연예인 선택은 어디꺼?',
#   datetime.date(2021, 11, 29),
#   'https://blog.naver.com/oddangzzigae/222581998990'),
#  (348,
#   '타낫 스트레이트 데님..트렌치 롱코트..',
#   datetime.date(2022, 4, 19),
#   'https://blog.naver.com/applepae/222704833964'),
#  (349,
#   '남자 롱코트 브랜드 데꼬로소 스타일 좋은 남자 겨울코트',
#   datetime.date(2021, 12, 30),
#   'https://blog.naver.com/ahs780324/222608236100'),
#  (350,
#   '기은세 인스타그램 사복 패션 옷은 미카이브 여자 롱코트',
#   datetime.date(2021, 10, 21),
#   'https://blog.naver.com/mallangjuice/222543583617'),
#  (351,
#   'JJ지고트 혜리의 여자 겨울 옷 핸드메이크 숏코트&롱코트 그리고 구스 패딩까지!',
#   datetime.date(2021, 11, 11),
#   'https://blog.naver.com/hanstar_94/222565143852'),
#  (352,
#   '겨울 오피스룩 오버핏 롱코트 코듀로이 팬츠 와이드 슬랙스',
#   datetime.date(2022, 2, 5),
#   'https://blog.naver.com/imagetech1/222639867760'),
#  (353,
#   '너를 닮은 사람 신현빈 마인 핸드메이드 코트! 30대 여자 롱코트 패션 추천',
#   datetime.date(2021, 10, 30),
#   'https://blog.naver.com/seojy8353/222553591389'),
#  (354,
#   '롱코트 덕후는 레드벨벳 웬디 출근길 패션의 에디토리얼비 찾아봄',
#   datetime.date(2022, 1, 30),
#   'https://blog.naver.com/hey_mystyle/222635058384'),
#  (355,
#   '펜싱 오상욱 김정환 옷 화보 패션 : 조르지오 아르마니 남자 캐시미어 니트 & 코듀로이 베스트 팬츠 & 롱코트...',
#   datetime.date(2021, 10, 8),
#   'https://blog.naver.com/marieeeee_/222530471893'),
#  (356,
#   '디자이너가방 모스티 코트백 롱코트 코디에 찰떡',
#   datetime.date(2022, 1, 25),
#   'https://blog.naver.com/rrsnow/222631164882'),
#  (357,
#   '라메레이 여성 겨울 롱코트 코디',
#   datetime.date(2021, 12, 5),
#   'https://blog.naver.com/kjy911203/222587280525'),
#  (358,
#   '[이스트하버서플러스]East Harbour Surplus Peter Long Coat[발마칸코트][롱코트][울코트][루어엣]',
#   datetime.date(2022, 2, 26),
#   'https://blog.naver.com/schsb2/222658494343'),
#  (359,
#   '여자 겨울 옷 가득한 JJ지고트 혜리 핸드메이드 숏코트와 롱코트 구스 패딩 이쁨!',
#   datetime.date(2021, 11, 9),
#   'https://blog.naver.com/pppmh0827/222562696400'),
#  (360,
#   '원마일웨어 스타일 애프터홈파티 오버핏 롱코트',
#   datetime.date(2022, 1, 8),
#   'https://blog.naver.com/lxx_yj__/222616603023'),
#  (361,
#   'DKNY미공홈에서 오픈 페이스 롱코트 왔어요',
#   datetime.date(2021, 12, 14),
#   'https://cafe.naver.com/smartbargain/1336082'),
#  (362,
#   '기은세 코트 패션 인스타그램 사복 옷 정보! 럭키슈에뜨 후드 롱코트 랍니다',
#   datetime.date(2021, 11, 23),
#   'https://blog.naver.com/2195321/222576431619'),
#  (363,
#   '기은세 인스타그램 체크 코트 패션 겨울에는 베네통 체크 컬렉션 숏,롱코트 다 있음♪',
#   datetime.date(2021, 11, 9),
#   'https://blog.naver.com/k_159500/222563047309'),
#  (731,
#   '남편 홈웨어?',
#   datetime.date(2022, 5, 1),
#   'https://cafe.naver.com/bbbx/574233'),
#  (364,
#   '남자 롱코트는 그냥 깔끔하게 코디하자',
#   datetime.date(2022, 1, 24),
#   'https://blog.naver.com/hong_e5865/222629913827'),
#  (365,
#   '디자이너 브랜드 모노크롬 2021 겨울 컬렉션 롱코트, 자켓, 니트로 분위기 있는 데일리룩 코디',
#   datetime.date(2021, 11, 12),
#   'https://blog.naver.com/iamchocolat/222566527271'),
#  (366,
#   '시스템 핸드메이드 롱코트',
#   datetime.date(2021, 11, 4),
#   'https://cafe.naver.com/hotdealcommunity/1654769'),
#  (367,
#   '[Tip] 롱코트를 도전하는 당신께 바치는 글.',
#   datetime.date(2021, 11, 28),
#   'https://cafe.naver.com/coredenim/823315'),
#  (368,
#   '40대분들 롱코트 입으세요?',
#   datetime.date(2021, 9, 28),
#   'https://cafe.naver.com/gloseems1/605313'),
#  (369,
#   '브라이트현 브라이트 셀린헤링본 울 롱코트 김나영코트추천, 밝을현',
#   datetime.date(2022, 1, 3),
#   'https://blog.naver.com/h_unny/222611359214'),
#  (370,
#   '남자 겨울 울 더블 롱코트 코디 / 누빔 안감 코트',
#   datetime.date(2021, 12, 19),
#   'https://blog.naver.com/chicupp/222598940278'),
#  (371,
#   '향❌)여자 롱코트',
#   datetime.date(2021, 12, 11),
#   'https://cafe.naver.com/perfumelove/925778'),
#  (372,
#   '핸드메이드 Y후드 롱코트(조이오브메이킹)',
#   datetime.date(2021, 12, 26),
#   'https://blog.naver.com/sewingstory/222605030219'),
#  (373,
#   '20211111 "롱코트&트레이닝복 내가 좋아하는 룩"',
#   datetime.date(2021, 11, 11),
#   'https://blog.naver.com/ekdgml/222565085785'),
#  (374,
#   '너를닮은사람 고현정 롱코트 브라운 막스마라 MAX MARA 골드체인 숄더백',
#   datetime.date(2021, 10, 29),
#   'https://blog.naver.com/kkomi8181/222552402748'),
#  (375,
#   '케네스콜 퀼팅 롱코트 두번째 구매',
#   datetime.date(2022, 1, 26),
#   'https://cafe.naver.com/ttoksun2/3681045'),
#  (376,
#   '8초 베이지 코듀로이 루즈핏 롱코트 샀어요',
#   datetime.date(2022, 1, 8),
#   'https://cafe.naver.com/smartbargain/1352607'),
#  (377,
#   '사내맞선 안효섭 롱코트 데꼬로소 30대 남자 봄 코디',
#   datetime.date(2022, 4, 29),
#   'https://blog.naver.com/tbtb--8282/222715798994'),
#  (378,
#   '별똥별 7회 오한별 이성경 옷 정보 벤시몽 플리스 롱코트',
#   datetime.date(2022, 5, 14),
#   'https://blog.naver.com/whit2sugar/222731743147'),
#  (379,
#   '*제작 프리미엄 앙고라울 아이보리 롱코트 한번더 봐주세요 :-)',
#   datetime.date(2021, 12, 1),
#   'https://blog.naver.com/laurel13/222583971415'),
#  (380,
#   '<신상> 포켓 양모 롱코트 (아이보리/ 소라 / 핑크)',
#   datetime.date(2021, 11, 25),
#   'https://blog.naver.com/omk27/222577861685'),
#  (381,
#   '한사람만 16회(마지막회) 김경남 옷, 패션 / 스튜디오 톰보이 롱코트',
#   datetime.date(2022, 2, 10),
#   'https://blog.naver.com/math3377/222643805591'),
#  (382,
#   '남자 롱코트 브랜드 추천해주세요!',
#   datetime.date(2021, 12, 13),
#   'https://cafe.naver.com/nyblog/1173581'),
#  (383,
#   '2022 여자 봄 롱코트 데일리룩',
#   datetime.date(2022, 3, 6),
#   'https://blog.naver.com/dmsql_0105/222664601344'),
#  (384,
#   '30대 남자 봄 코트 데꼬로소 롱코트 이때가 제격',
#   datetime.date(2022, 4, 10),
#   'https://blog.naver.com/mcteens/222696964177'),
#  (385,
#   '울캐시미어 테일러카라 롱코트',
#   datetime.date(2021, 12, 24),
#   'https://blog.naver.com/flow8906/222603453554'),
#  (386,
#   '카티아조 블랙레이블 프렌치 감성 롱코트 출시',
#   datetime.date(2021, 10, 21),
#   'https://blog.naver.com/fashion7071/222543961138'),
#  (387,
#   "[데일리룩] NO.695 - '토우에이지' 남자 오버핏 체크 롱코트를 활용해 겨울철 남친룩을 완성해보자 !!",
#   datetime.date(2021, 12, 20),
#   'https://blog.naver.com/po1265/222600164002'),
#  (388,
#   '타니즈 모투 스트랩 울 더블버튼 여자 롱코트 (a7731173-188b)',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/oqrs46d74/222743732741'),
#  (389,
#   '9회 별똥별 오한별 이성경 니트 가디건 코트 최지우 시우 퍼 롱코트 가방 크로스백 숄더백 김영대 공태성...',
#   datetime.date(2022, 5, 21),
# ...
#   'https://cafe.naver.com/smartbargain/1368126'),
#  (724,
#   '케즈 Keds 제니아 테일러 콜라보 홈웨어 티셔츠 플레이트 예뻐♥',
#   datetime.date(2021, 11, 2),
#   'https://blog.naver.com/yynopen/222556890476'),
#  (725,
#   '여성잠옷 나른 맨살파자마 인생 홈웨어 만났네',
#   datetime.date(2021, 12, 5),
#   'https://blog.naver.com/k4minlove/222587224025'),
#  (726,
#   '케즈 맨투맨 x 제니아 테일러 콜라보 홈웨어 편안해~ #Keds',
#   datetime.date(2021, 11, 5),
#   'https://blog.naver.com/hug387/222559538668'),
#  (727,
#   '봄 맞이 홈웨어',
#   datetime.date(2022, 4, 18),
#   'https://blog.naver.com/audreyson/222704093389'),
#  (728,
#   '여성잠옷, E루마 꿀잠 여성 잠옷 세트 파자마 홈웨어 실내복',
#   datetime.date(2022, 4, 13),
#   'https://blog.naver.com/princess5648/222699450496'),
#  (729,
#   '남성 체크바지 홈웨어, 데일리웨어로 만능 팬츠!',
#   datetime.date(2022, 2, 10),
#   'https://blog.naver.com/dbsqhr223/222644075279'),
#  (730,
#   '우리들의 블루스 4회 한지민 이영옥 옷 오프숄더 블라우스 점프수트 가디건 샌들 슈즈 파자마 홈웨어 패션...',
#   datetime.date(2022, 4, 18),
#   'https://blog.naver.com/jju6004/222703840777'),
#  (732,
#   '여름잠옷 잠옷 여성 예쁜 파자마 홈웨어 실내복 나시 반바지 추천',
#   datetime.date(2022, 5, 20),
#   'https://blog.naver.com/winner_aa/222739605182'),
#  (733,
#   '홈웨어에 진심인 제이니홈 라운지웨어 후기',
#   datetime.date(2022, 1, 25),
#   'https://blog.naver.com/2syeon/222631283542'),
#  (734,
#   '플라워프린트 로브세트 홈웨어',
#   datetime.date(2022, 3, 3),
#   'https://blog.naver.com/kimuimda/222661937184'),
#  (735,
#   '커플 홈웨어 후기 w/ 포그니포',
#   datetime.date(2022, 4, 24),
#   'https://blog.naver.com/elvira85/222710303923'),
#  (736,
#   '[주문폭주] 홈웨어 오늘밤 10시 마감 할게요 +목요일 발송 시작',
#   datetime.date(2022, 3, 30),
#   'https://blog.naver.com/lwyoung8/222686948067'),
#  (737,
#   '여자 카라 홈웨어 랏소베어 곰돌이 파자마 투피스(free)',
#   datetime.date(2022, 3, 31),
#   'https://blog.naver.com/soda1991/222688303533'),
#  (738,
#   '캐릭터 홈웨어 1 + 1 요미요미 귀요미 사랑스런 캐릭터 주니어 가능❤',
#   datetime.date(2022, 5, 10),
#   'https://cafe.naver.com/hotdealcommunity/1926166'),
#  (739,
#   '동상이몽 서하얀 블라우스 가방 홈웨어 핸드백 잠옷 임창정 아내 차분함이 매력적인 사람',
#   datetime.date(2022, 4, 5),
#   'https://blog.naver.com/bbabba223/222692239614'),
#  (740,
#   '홈웨어 추천 마리엔젤 라라엣 활동성이 편한 셔츠형 잠옷',
#   datetime.date(2022, 5, 1),
#   'https://blog.naver.com/poiu4123/222715141344'),
#  (741,
#   '2022 아이앱스튜디오 홈웨어 x 빅토리녹스 웍스아웃 래플 발매 정보',
#   datetime.date(2022, 5, 10),
#   'https://blog.naver.com/skytkdghk/222726683978'),
#  (742,
#   '힙스터 홈웨어 테클라(TEKLA) 한스타일에서 이젠 새벽배송으로 만나요!',
#   datetime.date(2022, 4, 9),
#   'https://blog.naver.com/lovexoqls/222695926309'),
#  (743,
#   '홈웨어!!!!!',
#   datetime.date(2022, 2, 13),
#   'https://cafe.naver.com/soho/2908343'),
#  (744,
#   '캐릭터 홈웨어 1 + 1 요미요미 귀요미 사랑스런 캐릭터 주니어 가능❤',
#   datetime.date(2022, 4, 27),
#   'https://cafe.naver.com/hotdealcommunity/1907713'),
#  (745,
#   '홈웨어 추천 남자 트렁크 에어길 이지팬츠',
#   datetime.date(2022, 5, 25),
#   'https://blog.naver.com/656a/222744448444'),
#  (746,
#   '더엑스(THE XXXY) 커플웨어_홈웨어(#1113) 후기에요~',
#   datetime.date(2022, 5, 5),
#   'https://cafe.naver.com/directwedding/4228293'),
#  (747,
#   '다작12. 홈웨어',
#   datetime.date(2022, 4, 26),
#   'https://cafe.naver.com/grayncgwx/70916'),
#  (748,
#   '자주 면 100% 홈웨어 홈드레스 2벌',
#   datetime.date(2022, 5, 10),
#   'https://cafe.naver.com/annasbazar/1737009'),
#  (749,
#   '메이시스 맨즈 홈웨어 티셔츠~~~',
#   datetime.date(2022, 3, 10),
#   'https://cafe.naver.com/newyorkgirlz/1141120'),
#  (750,
#   '잠옷&홈웨어&테리가운 공장 찾습니다.',
#   datetime.date(2022, 4, 10),
#   'https://cafe.naver.com/misinggo/993704'),
#  (751,
#   '동상이몽 서하얀 홈웨어 파자마 에블린 잠옷 이야',
#   datetime.date(2022, 4, 6),
#   'https://blog.naver.com/saaaa03/222693047360'),
#  (752,
#   '한나센스 여성용트렁크 여름 홈웨어로 편하게 사각팬티입자!',
#   datetime.date(2022, 4, 9),
#   'https://blog.naver.com/sumin_1216/222696253949'),
#  (753,
#   '[ 싸이클린 부드러운 유기농 트렁크팬티 ] 집순이에게 최고의 홈웨어 여자 트렁크팬티 추천',
#   datetime.date(2022, 5, 22),
#   'https://blog.naver.com/xwh48x/222741532928'),
#  (754,
#   '간만의 올 겨울 데일리룩(feat. 샤넬, 오이쇼 홈웨어)',
#   datetime.date(2022, 2, 1),
#   'https://cafe.naver.com/nyblog/1232048'),
#  (755,
#   '모드린 핑크블라썸여성 홈웨어 홈웨어원피스',
#   datetime.date(2022, 5, 19),
#   'https://blog.naver.com/bk931202/222738243681'),
#  (756,
#   '♡편하게 입을 홈웨어 팬츠 ♡',
#   datetime.date(2022, 2, 19),
#   'https://cafe.naver.com/ggong2/975675'),
#  (757,
#   '남녀공용 스테이홈 반팔 마약잠옷 서둘러야 하는 홈웨어 이유가 다 있지용',
#   datetime.date(2022, 4, 26),
#   'https://cafe.naver.com/hotdealcommunity/1906252'),
#  (758,
#   '홈웨어 상의하의 세트 바로발송 결제창오픈 :)',
#   datetime.date(2022, 3, 14),
#   'https://blog.naver.com/seoyun0221/222672250088'),
#  (759,
#   '잠옷 커플잠옷 잠옷세트 홈웨어 홈웨어룩 파자마 블로그마켓추천',
#   datetime.date(2022, 5, 25),
#   'https://blog.naver.com/quffk12/222745560995'),
#  (760,
#   '홈웨어 반바지 물랑루즈 파스텔 여성트렁크 편해요',
#   datetime.date(2022, 4, 30),
#   'https://blog.naver.com/pinkmariaa/222716862445'),
#  (761,
#   '실크 슬립원피스 파자마 고급지고 편한 홈웨어 ♡',
#   datetime.date(2022, 5, 21),
#   'https://blog.naver.com/hjrang0606/222740316435'),
#  (762,
#   '[블루밍 민소매 잠옷세트] 국내제작 시원한 여름 홈웨어 아사면 러블리 파자마 꽃무늬 실내복 레이스 잠옷바지',
#   datetime.date(2022, 5, 17),
#   'https://blog.naver.com/ce_soir_/222736127789'),
#  (763,
#   '홈웨어 피팅모델 모집합니다.',
#   datetime.date(2022, 4, 29),
#   'https://cafe.naver.com/soho/2981982'),
#  (764,
#   '[올렛스룸] 홈웨어도 예쁘게! 여름에 입기 좋은 박스티!',
#   datetime.date(2022, 5, 25),
#   'https://blog.naver.com/habiollet/222744529119'),
#  (765,
#   '홈 웨어원피스 홈웨어 투피스세트 집에서 마구 입어질 데일리 룩❤❤',
#   datetime.date(2022, 4, 24),
#   'https://cafe.naver.com/hotdealcommunity/1902874'),
#  (766,
#   '[쇼핑] 아래 로마리타님 글 보고 홈웨어 추천하러왔죠!!',
#   datetime.date(2022, 5, 8),
#   'https://cafe.naver.com/towngtx1/91202'),
#  (767,
#   '홈웨어 다들 입으시나요~?',
#   datetime.date(2022, 3, 29),
#   'https://cafe.naver.com/ira111/614426'),
#  (768,
#   '파자마 바지 어디꺼 입으시나요?!+홈웨어 뭐 입으세요?',
#   datetime.date(2022, 2, 11),
#   'https://cafe.naver.com/casuallydressed/447295'),
#  (769,
#   '리미떼 홈웨어 외출복으로',
#   datetime.date(2022, 4, 18),
#   'https://cafe.naver.com/lovehayden/4140744'),
#  (770,
#   '사이즈 넉넉한 홈웨어',
#   datetime.date(2022, 3, 11),
#   'https://cafe.naver.com/sujilovemom/509645'),
#  (771,
#   '이런거 홈웨어예요.?',
#   datetime.date(2022, 4, 24),
#   'https://cafe.naver.com/kdnstorys/584824'),
#  (772,
#   '잠옷이나 홈웨어 어디서 사시나요?',
#   datetime.date(2022, 4, 10),
#   'https://cafe.naver.com/bluegray28rsc/538247'),
#  (773,
#   '잠옷 (홈웨어. 패밀리룩) 전문 프로모션 업체 찾습니다~',
#   datetime.date(2022, 4, 20),
#   'https://cafe.naver.com/misinggo/998153'),
#  (774,
#   '낭만옷장안나 홈웨어 상하세트, 내츄럴잠옷 상하세트, 원피스잠옷',
#   datetime.date(2022, 3, 13),
#   'https://cafe.naver.com/mjann/3095849'),
#  (775,
#   '홈웨어나 일상에서 편하게~',
#   datetime.date(2022, 5, 10),
#   'https://cafe.naver.com/usem/1861972'),
#  (776,
#   '허그미달링->플라워 홈웨어(새상품)',
#   datetime.date(2022, 4, 20),
#   'https://cafe.naver.com/cosmania/34506086'),
#  (777,
#   '온앤온 트위드 자켓 결혼식 하객룩으로 좋아',
#   datetime.date(2022, 2, 8),
#   'https://blog.naver.com/ssdria/222642107472'),
#  (778,
#   '여성트위드자켓 핑크 셔츠카라로 시크하게',
#   datetime.date(2022, 5, 22),
#   'https://blog.naver.com/xixhk/222740770238'),
#  (779,
#   '여자 봄패션 블라우스 코디 트위드자켓 내돈내산후 해본 후기!',
#   datetime.date(2022, 3, 31),
#   'https://blog.naver.com/bushcherry1/222687734857'),
#  (780,
#   '어김없이 트위드의 계절이돌아왔다! (feat. 하객룩)',
#   datetime.date(2022, 3, 24),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=33507989&amp;memberNo=25590338&amp;vType=VERTICAL'),
#  (781,
#   'moodndress 린넨반팔트위드자켓 여름자켓 반팔자켓 골드버튼자켓 여름코디 마켓',
#   datetime.date(2022, 5, 25),
#   'https://blog.naver.com/moodndress/222745763570'),
#  (782,
#   '바바더닷컴 품격있는 김남주 토탈케어로 여름준비! 반팔 트위드 자켓 예쁨',
#   datetime.date(2022, 5, 23),
#   'https://blog.naver.com/k_159500/222741991403'),
#  (783,
#   '리사 화보 패션 옷 가방 부츠 신발 정리편! 셀린느 미니백 가방, 트리옹프 체인 숄더백 & 트위드자켓 & 부츠',
#   datetime.date(2022, 4, 21),
#   'https://blog.naver.com/zldnld99/222707542636'),
#  (784,
#   '[여성 여름자켓 추천★] 여성 린넨자켓, 가디건, 반팔트위드자켓 으로 시원하게 감성더하기!',
#   datetime.date(2022, 5, 3),
#   'https://post.naver.com/viewer/postView.naver?volumeNo=33734698&amp;memberNo=35404784&amp;vType=VERTICAL'),
#  (785,
#   '더리얼리얼 산드로 트위드 자켓',
#   datetime.date(2022, 4, 14),
#   'https://cafe.naver.com/nyblog/1317065'),
#  (786,
#   '자라 ZARA 트위드 자켓 후기 & 코디 (내돈내산)',
#   datetime.date(2022, 2, 21),
#   'https://blog.naver.com/jayuyu/222653603791'),
#  (787,
#   '봄자켓(큐티자켓), 트위드자켓 패키지 공구합니다.',
#   datetime.date(2022, 2, 14),
#   'https://blog.naver.com/jinhi721/222646825112'),
#  (788,
#   '산드로 새로 산 트위드 자켓 입은 토욜',
#   datetime.date(2022, 3, 26),
#   'https://cafe.naver.com/smartbargain/1399975'),
#  (789,
#   '산드로 미국공홈 50%+추가20% 세일!!! 설현 니트, 웬디 스웻셔츠, 트위드 자켓 등',
#   datetime.date(2022, 4, 29),
#   'https://blog.naver.com/berryeunice/222714927406'),
#  (790,
#   'PINKO 핀코 트위드자켓 데일리룩 & 파페치 3월 할인코드 전 회원 -15% 혜택 !',
#   datetime.date(2022, 3, 17),
#   'https://blog.naver.com/llmement/222675386277'),
#  (791,
#   "루에브르 크로스백 가방 '삭 드 쟈당' 트위드자켓 까지",
#   datetime.date(2022, 4, 5),
#   'https://blog.naver.com/iamheozzang/222691850619'),
#  (792,
#   '타임 핑쿠 트위드 자켓 개시! 플플 미스트와 랩스커트와 함께! (뚱허리의 넣입 도저어어언!)',
#   datetime.date(2022, 5, 24),
#   'https://cafe.naver.com/smartbargain/1428914'),
#  (793,
#   '독육스 산드로 이자벨라 크롭트 트위드 자켓',
#   datetime.date(2022, 5, 25),
#   'https://cafe.naver.com/nyblog/1351107'),
#  (794,
#   '마쥬 트위드자켓 너무 이뿌네요',
#   datetime.date(2022, 5, 17),
#   'https://cafe.naver.com/nyblog/1345884'),
#  (795,
#   '미뉴에트_간절기 반팔트위드 자켓',
#   datetime.date(2022, 5, 21),
#   'https://blog.naver.com/ehxhflanrqkq/222741090406'),
#  (796,
#   '20대, 30대 여성 트위드 자켓 코디 - 트위드 가디건 크롭 자켓 투피스 셋업 추천',
#   datetime.date(2022, 2, 17),
#   'https://blog.naver.com/syous0/222649713883'),
#  (797,
#   '봄 트위드 자켓 베이비키스 옐로우 화사해',
#   datetime.date(2022, 5, 1),
#   'https://blog.naver.com/sikhye0701/222717022193'),
#  (798,
#   '딘디 데일리룩 - 오브오브 트위드 자켓, 굿덴 데님 와이드 청바지, 바이파 샌들/가방, 시몬로샤 머리핀',
#   datetime.date(2022, 4, 21),
#   'https://blog.naver.com/tlswlgprjt/222707470572'),
#  (799,
#   '아이비 반팔 트위드 자켓 & 스커트 투피스 코디♥ 조이그라이슨 의류-',
#   datetime.date(2022, 5, 5),
#   'https://blog.naver.com/hug387/222721410996'),
#  (800,
#   '여름 하객룩 트위드자켓 민트 여자 출근룩 데이트룩 코디',
#   datetime.date(2022, 5, 11),
#   'https://blog.naver.com/oldpopsong/222727959052'),
#  (801,
#   '썸머트위드자켓 후기 (추가 착샷)',
#   datetime.date(2022, 5, 18),
#   'https://blog.naver.com/omk27/222737460518'),
#  (802,
#   '전참시 서현 옷 패션! 듀엘 코트, 트위드 자켓, 원피스, 가디건, 스커트',
#   datetime.date(2022, 2, 22),
#   'https://blog.naver.com/marieeeee_/222654210661'),
#  (803,
#   '여자봄코디 트위드자켓 샤넬코코핸들',
#   datetime.date(2022, 5, 9),
#   'https://blog.naver.com/smekdbs/222725587246'),
#  (804,
#   '마인 트위드 자켓 샀어요^^',
#   datetime.date(2022, 4, 3),
#   'https://cafe.naver.com/smartbargain/1404031'),
#  (805,
#   'Maje 마쥬 여성 반팔 니트 코디! 트위드 자켓, 마린세르 파페치 4월 할인코드 만나',
#   datetime.date(2022, 4, 10),
#   'https://blog.naver.com/blingnas/222697003409'),
#  (806,
#   '클래식트위드자켓 크림 바로 배송 2점 그리고 하이리넨자켓 !',
#   datetime.date(2022, 4, 3),
#   'https://blog.naver.com/p2943/222690684895'),
#  (807,
#   '7부소매 노카라트위드자켓',
#   datetime.date(2022, 3, 30),
#   'https://blog.naver.com/pppkiki/222686568799'),
#  (808,
#   '2일간판매)아우든 트위드 자켓 여름 코디',
#   datetime.date(2022, 5, 24),
#   'https://blog.naver.com/s_rosa/222743982905'),
#  (809,
#   '루에브르 임현주 화보 22 여름 신상 (feat, 인스타그램) 여자 가방, 원피스, 반팔 트위드 자켓',
#   datetime.date(2022, 4, 22),
#   'https://blog.naver.com/sh_theme/222708534841'),
#  (810,
#   '바이린샵 전여빈 패션 옷 화보 : 여자 원피스 트위드 자켓 스커트 수트 트렌치코트로 봄 하객룩',
#   datetime.date(2022, 3, 19),
#   'https://blog.naver.com/jenny8428/222676797196'),
#  (811,
#   '전여빈 패션 옷 화보, 바이린샵 봄 원피스 트위드 자켓 스커트 수트 트렌치코트 여자 오피스룩',
#   datetime.date(2022, 3, 20),
#   'https://blog.naver.com/jeongwon84/222678271837'),
#  (812,
#   '셔링 쿨니트가디건. 연데님핀턱 반바지.몬트 썸머스트링팬츠.올리브 볼캡.레몬트윌 트위드자켓. 머드뮬슬리퍼',
#   datetime.date(2022, 5, 11),
#   'https://blog.naver.com/mani0005/222728778888'),
#  (813,
#   '코벳블랑 X 젤라비 화보 속 여성 봄 블라우스 트위드자켓 코디 살펴봐요',
#   datetime.date(2022, 3, 25),
#   'https://blog.naver.com/yynopen/222682734004'),
#  (814,
#   '레터 버나뎃 트위드 자켓. LETTER Bernadette tweed jacket',
#   datetime.date(2022, 5, 20),
#   'https://blog.naver.com/0_0jjjjjj/222739783480'),
#  (815,
#   '리얼리얼 마쥬 트위드 자켓',
#   datetime.date(2022, 5, 10),
#   'https://cafe.naver.com/smartbargain/1422561'),
#  (816,
#   '대박 트위드자켓!!!!!!!!!!!!',
#   datetime.date(2022, 3, 26),
#   'https://blog.naver.com/vllikwillv/222683512883'),
#  (817,
#   '헤브 트위드 퍼프 자켓 (하객룩 추천)',
#   datetime.date(2022, 5, 13),
#   'https://blog.naver.com/minkue7/222731305897'),
#  (818,
#   '송혜교 화보 패션 : 미샤(MICHAA) 트위드 자켓, 스커트 셋업 추천',
#   datetime.date(2022, 4, 12),
#   'https://blog.naver.com/rudelulu/222697956476'),
#  (819,
#   '트위드자켓 코디 모음 셀린느 샤넬 컬렉션 외+눈호강',
#   datetime.date(2022, 3, 11),
#   'https://blog.naver.com/farbemaria/222669810771'),
#  (820,
#   '[룩캐스트] 칼리아 트리밍 트위드 자켓 셋업 매장 입고 안내',
#   datetime.date(2022, 5, 12),
#   'https://blog.naver.com/lookast/222729777050'),
#  (821,
#   'JJ지코트 혜리 데이트룩 제안 트위드 자켓, 원피스 사랑스러운 여자 봄옷',
#   datetime.date(2022, 2, 28),
#   'https://blog.naver.com/sasa9508/222659770203'),
#  (822,
#   '트위드자켓,더 예쁘게 수선해서 입어요~',
#   datetime.date(2022, 4, 20),
#   'https://blog.naver.com/didodidi/222705929071'),
#  (823,
#   '보석트위드자켓 / 트렌치 벨트 원피스 // 하객룩 / 봄코디 / 륀제이',
#   datetime.date(2022, 4, 5),
#   'https://blog.naver.com/wusl2524/222692263077'),
#  (824,
#   '(코디컷 추가) 봄자켓, 부클 트위드자켓, 로퍼 마켓 진행 중!',
#   datetime.date(2022, 2, 21),
#   'https://blog.naver.com/wrusu/222653927993'),
#  (825,
#   '트위드 자켓 2종 균일가로 v넥,R넥✅✅',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/hotdealcommunity/1943717'),
#  (826,
#   '미쏘(MIXXO) 반팔 트위드 크롭자켓으로 데일리룩!',
#   datetime.date(2022, 5, 21),
#   'https://blog.naver.com/ych9749/222741114077'),
#  (827,
#   '노카라 퍼프소매 히든버튼 숏 트위드자켓',
#   datetime.date(2022, 4, 7),
#   'https://blog.naver.com/hi_rit/222694575568'),
#  (828,
#   '완료 [ 칼 라거펠트 ] 트위드 자켓',
#   datetime.date(2022, 4, 8),
#   'https://blog.naver.com/kate_young/222695048586'),
#  (829,
#   '봄에 잘 어울리는 트위드자켓 코디',
#   datetime.date(2022, 2, 25),
#   'https://blog.naver.com/gninterma/222657541235'),
#  (830,
#   '정호연 쉬즈미스 트위드자켓 예쁘네요',
#   datetime.date(2022, 5, 25),
#   'https://cafe.naver.com/famsale/2557699'),
#  (831,
#   '사랑의 꽈배기 99회 100회 손성윤 함은정 김주리 옷 트위드 자켓 원피스 가방 의상 협찬 스타일',
#   datetime.date(2022, 5, 17),
#   'https://blog.naver.com/jju6004/222736327747'),
#  (832,
#   '자라 매장에서 트위드 자켓 입어봤어요 :)',
#   datetime.date(2022, 3, 24),
#   'https://cafe.naver.com/smartbargain/1398688'),
#  (833,
#   '아이비 인스타그램 속 트위드자켓, 조이그라이슨 의류',
#   datetime.date(2022, 5, 8),
#   'https://blog.naver.com/pingu422/222724584850'),
#  (835,
#   '독마쥬 아울렛 트위드 자켓 왔어요',
#   datetime.date(2022, 3, 4),
#   'https://cafe.naver.com/nyblog/1270454'),
#  (836,
#   '독마쥬 핑크트위드 자켓 왔어요(스크류바)',
#   datetime.date(2022, 3, 10),
#   'https://cafe.naver.com/smartbargain/1390349'),
#  (837,
#   '우리는오늘부터 6회 오우리 임수향 성훈 신동욱 홍지윤 옷 니트 가디건 스웨터 트위드 자켓 진주 피어싱...',
#   datetime.date(2022, 5, 25),
#   'https://blog.naver.com/some1it_/222745093028'),
#  (838,
#   '지금부터 쇼타임 진기주 인스타 트위드자켓 패션 @무디디',
#   datetime.date(2022, 5, 21),
#   'https://cafe.naver.com/cosmania/34664104'),
#  (839,
#   '마쥬 트위드 자켓이 왔어용 (마쥬가 왜 트위드맛집인지 알겠는...‼️)',
#   datetime.date(2022, 3, 17),
#   'https://cafe.naver.com/nyblog/1284779'),
#  (840,
#   '썸머 노카라 반팔 트위드자켓 3color',
#   datetime.date(2022, 5, 12),
#   'https://blog.naver.com/qsxc1995/222730019471'),
#  (841,
#   '트위드 자켓',
#   datetime.date(2022, 3, 15),
#   'https://cafe.naver.com/young08277/40276'),
#  (842,
#   '(sfera) 스페라 신상~!! ~ 쇼트 트위드 자켓+팬츠',
#   datetime.date(2022, 5, 16),
#   'https://cafe.naver.com/mompl/558290'),
#  (843,
#   '보카바카 트위드 자켓 보자마자 구매 ㅠㅠㅠㅠ',
#   datetime.date(2022, 5, 11),
#   'https://cafe.naver.com/fox5282/3239033'),
#  (844,
#   '삭스 띠어리 실크 셔츠원피스 4사이즈 / 자라 겨울세일 트위드자켓 xs',
#   datetime.date(2022, 5, 11),
#   'https://cafe.naver.com/smartbargain/1423207'),
#  (845,
#   '정혜성 인스타그램 사복 패션 <에몽 트위드 자켓 & 바이미나 부츠>',
#   datetime.date(2022, 5, 12),
#   'https://cafe.naver.com/cosmania/34623128'),
#  (846,
#   '시스템옴므 / 트위드 자켓 / 100',
#   datetime.date(2022, 5, 9),
#   'https://cafe.naver.com/2ndkalsuma/4185771'),
#  (847,
#   '르망고 트위드자켓 (L)',
#   datetime.date(2022, 5, 23),
#   'https://cafe.naver.com/swimmingholicclub/750249'),
#  (848,
#   '여성복.트위드자켓.주름원피스.바지',
#   datetime.date(2022, 5, 18),
#   'https://cafe.naver.com/byungs94/7017447'),
#  (849,
#   '숲 트위드자켓(새것.블랙)',
#   datetime.date(2022, 5, 25),
#   'https://cafe.naver.com/jinhaemam/1974156'),
#  (850,
#   '스코틀랜드 해리스트위드 울자켓 36사이즈',
#   datetime.date(2022, 5, 22),
#   'https://cafe.naver.com/ttoksun2/4095629'),
#  (851,
#   '21마인 인기브레이드 트위드 자켓-에눌',
#   datetime.date(2022, 5, 17),
#   'https://cafe.naver.com/parisienlook/3550105'),
#  (852,
#   '막스마라라인 페니블랙 발코네 트위드 자켓 Balcone',
#   datetime.date(2022, 5, 13),
#   'https://cafe.naver.com/ttoksun2/4064692'),
#  (853,
#   '칙스라벨 하트 트위드 자켓',
#   datetime.date(2022, 5, 13),
#   'https://cafe.naver.com/parisienlook/3542682'),
#  (854,
#   '트리밍버드 트위드자켓 팝니다',
#   datetime.date(2022, 5, 8),
#   'https://cafe.naver.com/cosmania/34600482'),
#  (855,
#   'sandro 산드로 트위드 자켓',
#   datetime.date(2022, 5, 2),
#   'https://cafe.naver.com/yjoutlet/3825209')]

# %%
#db 연결 종료
conn.cursor().close()
conn.close()
